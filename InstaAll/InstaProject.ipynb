# %%
from numpy.random import choice
import numpy as np
import traceback
import regex
import datetime
import re
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep, strftime
from random import randint
import random
import pandas as pd

#todo use headless_browser
chromedriver_path = 'C:/Users/farha/Desktop/DESKTOP_FILES/ColorSplash/Main_Insta/chromedriver.exe' # Change this to your own chromedriver path!
webdriver = webdriver.Chrome(executable_path=chromedriver_path)
sleep(2)
webdriver.get('https://www.instagram.com/accounts/login/?source=auth_switcher')
sleep(3)

# %%
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 1000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
username = webdriver.find_element_by_name('username')
username.send_keys('i.am.the.swagger')
password = webdriver.find_element_by_name('password')
password.send_keys('mypassword')
sleep(2)

# %%
# Append-adds at last 
#create logfiles for storing data
file1 = open("logfile.txt","a+")#append mode 
file1.write("--New Run-- \n")
file1.write('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
file1.write("\nEntering Iterations \n\n\n")
#file1.close()
# Out:
# 24

# %%
try:
    button_login = webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/article/div/div[1]/div/form/div[4]/button')
except:
    button_login = webdriver.find_element_by_xpath('/html/body/div[1]/section/main/article/div[2]/div[1]/div/form/div[4]/button/div')
button_login.click()
sleep(3)

# %%
try:
    notnow = webdriver.find_element_by_xpath('/html/body/div[4]/div/div/div[3]/button[2]')
    notnow.click() #comment these last 2 lines out, if you don't get a pop up asking about notifications
    sleep(randint(1,2))
except:
    pass

# %%
try:
    cancel = webdriver.find_element_by_xpath('/html/body/div[3]/div/div/div[3]/button[2]')
    cancel.click() #comment these last 2 lines out, if you don't get a pop up asking about notifications
    sleep(randint(1,2))
except:
    pass

# %%
#use hashtags
hashtag_list = [ 'deeplearning','ai','colorsplash','artificialintelligence','airevolution','machinelearning',
                'neuralnetworks','deeplearning','influencer','blogger','mensfashion','indiangirls'
               ,'indianfashion','indiangirl','indian','traditonal','fashionindia','indianfashion',
               'fashionindia','kolkata','art','kolkata','kolkatafashion','indiafashion','deepdream',
               'indiangentlemen','aimforclass','traditional','indianmodel','fashionbloggers','indianart',
                'coding','digitalart','indianinfluencers','aimforclass','indianbloggers','indianfashion',
               'fashionindia','indian','indianblog','indianmodels','indianmodel','indianlook','indianmodels'
               ,'fire','staydashing'] 
webdriver.get('https://www.instagram.com/explore/tags/'+ hashtag_list[-1] + '/')
sleep(randint(4,9))

# %%
#get all thumbnail links
#best working
posts=[]
all_links=[]
for i in range(120):
    elems = webdriver.find_elements_by_xpath("//a[@href]")
    for elem in elems:
        post_link=elem.get_attribute("href")
        #print(post_link)
        if post_link not in all_links:
            all_links.append(post_link)
        if(re.search("^https://www.instagram.com/p/.", post_link)):
            if post_link not in posts:
                posts.append(post_link)
    webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    if len(posts)>=6000:
        break
    sleep(randint(2,4))
print(len(posts))
print(len(all_links))
# Out:
# 486
# 501

# %%
def get_int(followers):
    thou=False
    if(re.search('k',followers)):
        #followers=followers.replace('k','000')
        thou=True
    followers=followers.replace(',','')
    temp = re.findall(r'\d+', followers) 
    res = list(map(int, temp)) 
    if thou:
        res[0]=res[0]*1000
    return res[0]

def print_list(lst):
    for i in lst:
        print(i)

# %%
file2=open("visited_users.txt","r+")
visited_users = file2.readlines()
#file2.write("Running..................\n")
for i in range(len(visited_users)):
    visited_users[i]=visited_users[i].strip()

    
file3=open("visited_posts.txt","r+")
visited_posts = file3.readlines()
#file3.write("Running..................\n")
for i in range(len(visited_posts)):
    visited_posts[i]=visited_posts[i].strip()
#print(visited_users)
#file2.close()

# %%
#webdriver.quit()
#visited_users = open("visited_users.txt").readlines()
#print(visited_users)

#for i in range(len(visited_users)):
#visited_users[i]=visited_users[i].strip()

#print(visited_users)

# %%
# Append-adds at last 
#create logfiles for storing data
#file2 = open("visited_users.txt","a")#append mode 


#https://stackoverflow.com/questions/56381066/how-to-open-file-in-read-and-append-mode-in-python-at-the-same-time-in-one-varia

# %%
file_users = open("users_followed.txt","a+")#append mode 
file_users.write("--New Run-- \n")
file_users.write('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
file_users.write("Running ....\n")

file_messaged = open("users_messaged.txt","a+")#append mode 
file_messaged.write("--New Run-- \n")
file_messaged.write('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
file_messaged.write("Running ....\n")

file_commented = open("users_commented.txt","a+")#append mode #user #comment #post
file_commented.write("--New Run-- \n")
file_commented.write('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
file_commented.write("Running ....\n")

file_liked = open("users_liked.txt","a+")#append mode 
file_liked.write("--New Run-- \n")
file_liked.write('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))
file_liked.write("Running ....\n")
# Out:
# 13

# %%
#for item in followed_users:
#file_users.write("%s\n" % item)

# %%
#for fashion and other stuff
#v2.0 no messaging
#do the main thing
hashtag_posts=posts
counter=0
big_count=0

for post in hashtag_posts:
    big_count+=1
    print("Looping runs : ",big_count)
    try:
        if post in visited_posts:
            continue

        visited_posts.append(post)
        file3.write(str(post)+"\n")
        #{loop post_tag open
        print("\nCurrent Post : ",post)
        file1.write("\nCurrent Post : "+str(post)+"\n")
        #limit too many interactions
        file1.write("\nCounter Value : "+str(counter)+"\n")
        print("\nCounter Value : "+str(counter)+"\n")
        
        file1.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file1.fileno())
        file2.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file2.fileno())
        file3.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file3.fileno())
        file_users.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_users.fileno())
        file_messaged.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_messaged.fileno())
        file_commented.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_commented.fileno())
        file_liked.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_liked.fileno())
        
        if(counter>=150):
            print("User activity max reached!!")
            file1.write("\nUser activity max reached!!\n")
            file1.close()
            file2.close()
            file_users.close()
            file_messaged.close()
            file_commented.close()
            file_liked.close()
            break  
        webdriver.get(post)
        sleep(randint(6,9))

        #link of id
        goto_ids=[ '/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/div[2]/div[1]/ul/div/li/div/div/div[2]/h2/div/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/header/div[2]/div[1]/div[1]/a']
        #access the id link
        for idx in goto_ids:
            try:
                goto_id=webdriver.find_element_by_xpath(idx)
                break
            except:
                continue

        lead=goto_id.text
        print("Current User: ",lead)
        file1.write("Current User: "+str(lead)+"\n")
        if lead in visited_users:
            continue

        visited_users.append(lead)
        file2.write(str(lead)+"\n")
        goto_id.click()
        sleep(randint(2,6))
        

        #get followers and following
        try:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
            followers=get_int(followers_element.text)
        except:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/ul/li[2]/a/span')
            followers=get_int(followers_element.text)

        print("Followers :",followers)
        sleep(randint(4,10))
        file1.write("Followers :"+str(followers)+"\n")

        try:
            following_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
        except:
            #followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
            print("Err")

        following=get_int(following_element.text)
        print("Following :",following)
        file1.write("Following :"+str(following)+"\n")
        sleep(randint(4,10))


        if((following>followers) or (followers<601)):
            #{user loop open
            print("Found user!!!!")
            file1.write("Found user!!!!"+"\n")
            try:
                #follow_probability=randint(1,10)
                follow_probability=1
                if (follow_probability<=2):
                    follow_button = webdriver.find_element_by_xpath('//button[text()="Follow"]')
                    follow_button.click()
                    sleep(randint(5,10))
                    file1.write(str(lead)+" Followed \n")
                    file_users.write(str(lead)+" \n")
            except:
                #file1.write(lead+" Error Following \n")
                print(str(lead)+" Error Following \n")
                file1.write(str(lead)+" Error Following \n")
                pass
            sleep(randint(4,7))

            #then do the liking and commenting and messaging (if possible)
            #messaging
            
            try:
                # Comments and tracker
                messages=[' https://www.instagram.com/p/B_VDVyBp08G/  Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B-ZeWRwJuZR/  Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8E0ChNpPWi/  Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8yRJUVpW98/  Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8yKLJYJGO3/  Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          " https://www.instagram.com/p/B_VDVyBp08G/ Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B-ZeWRwJuZR/  Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B8E0ChNpPWi/ Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B8yRJUVpW98/ Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B_VDVyBp08G/Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          ' https://www.instagram.com/p/B_VDVyBp08G/ Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/  Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B8yRJUVpW98/ Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/ Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/  I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B8yRJUVpW98/ I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B_VDVyBp08G/I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ Your support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B-ZeWRwJuZR/  Your support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B8E0ChNpPWi/ Your support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B8yRJUVpW98/ Your support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B_VDVyBp08G/Your support has always been amazing ! Do give me a thumbs up if you liked my post!']
                message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
                message_button.click()
                sleep(randint(3,6))
                message=random.choice(messages)
                
                try:
                    message_box=webdriver.find_elements_by_tag_name('textarea')
                    message_box[0].send_keys(message)
                except:
                    message_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[2]/div/div[2]/div/div/div[2]/textarea')
                    message_box.send_keys(message)
                
                sleep(randint(2,4))
                send_button=webdriver.find_element_by_xpath('//button[text()="Send"]')
                send_button.click()
                file1.write(lead+" Messaged "+message+" \n")
                file_messaged.write(lead+" : Messaged : "+message+" \n")
                messaged_users.append(str(lead)+"||"+str(message))
                sleep(1)
                info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
                info_button.click()
                move_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div/div[2]/div[2]/div[1]/button')
                move_button.click()
                sleep(randint(2,10))
                file1.write(" Moved message \n")
                print("Sent message \n")
            except:
                file1.write(lead+" Messaged Failed "+message+" \n")
                print(lead+" Messaging Failed "+message+" \n")
                pass
            
            counter+=1

            webdriver.get('https://www.instagram.com/'+ lead + '/')

            #first get all post links of this user
            #best working
            user_posts=[]
            for i in range(5):
                elems = webdriver.find_elements_by_xpath("//a[@href]")
                for elem in elems:
                    post_link=elem.get_attribute("href")
                    #print(post_link)
                    if(re.search("^https://www.instagram.com/p/.", post_link)):
                        if post_link not in user_posts:
                            user_posts.append(post_link)
                webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
                if len(user_posts)>=500:
                    break
                sleep(randint(2,4))
            print("Got user posts!!")
            file1.write(" Got user posts!! \n")
            


            #get posts to be liked recent posts preferred
            #probability play comes here
            length=len(user_posts)
            probabilities = [0] * length
            for i in range(length):
                probabilities[i]=(length-i)/length
            probabilities = np.array(probabilities)
            probabilities /= probabilities.sum()  # normalize
            randomElement = choice(user_posts, p=probabilities)
            max_likes=randint(3,5)
            likes=[]
            for i in range(max_likes):
                randomElement = choice(user_posts, p=probabilities)
                likes.append(randomElement)
            #for each_like in likes:
            #print(user_posts.index(each_like))
            #everything happenning under main user try

            print("Travelled so far")
            #give actual likes and comments
            for each_like in likes:
                #{
                file1.write(lead+" Liking Post - "+str(each_like)+" \n")
                print(str(lead)+" Liking Post - "+str(each_like)+" \n")
                #goto_post=webdriver.get(each_like)
                webdriver.get(each_like)
                sleep(randint(2,4))
                like_buttons=[ '/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button']
                for idx in like_buttons:
                    try:
                        #liketry open
                        like_button=webdriver.find_element_by_xpath(idx)
                        #break
                        #liketry close
                    except:
                        file1.write(str(lead)+" Failed to like!!!- "+str(each_like)+" \n")
                        tb_message=traceback.format_exc()
                        file1.write(" Full Traceback- "+str(tb_message)+" \n")
                        continue
                like_button.click()
                file_liked.write(str(lead)+" : Post Liked : "+str(each_like)+" \n")
                sleep(randint(2,4))
                print(str(lead)+" Post Liked - "+str(each_like)+" \n")
                file1.write(str(lead)+" Post Liked - "+str(each_like)+" \n")
                # Comments and tracker
                comm_prob = randint(1,10)

                #comm_prob=10
                comments=["Hey,I found your profile really mind-blowing! Mind checking back mine?",
                            "Your profile is really amazing,I found your posts the best on Intsagram today! Do check back my profile too!",
                            "I really enjoyed scrolling through your posts! Do like mine if you reciprocate!",
                            "Hey,I found your feed really awesome! One of the very best today!! Do check out my profile too!",
                            "This profile is one of the best things I found on instagram today! #the_best_gallery",
                            "Wow! Your instagram handle is really cool! ",
                            "TBH, I seriously love how expressive your work is. ;D ",
                            "If any pic ever deserved a love react it’s this one!",
                            "I don’t know if you’re aware, but you're gonna be famous pretty soon. #Amazing posts :X",
                            "Your feed is so very aesthetic! I simply enjoyed scrolling through it a lot! :)",
                            "Thats a really dashing picture!:0",
                            "I really like your insta!:p"]
                comment=random.choice(comments)
                print("random comment chosen!")
                #if comment probability>90% then only comment 
                try:
                    if comm_prob > 6:
                        print("CommentBox successful")
                        file1.write(str(lead)+" Trying commenting - "+str(each_like)+" \n")
                        sleep(randint(4,10))
                        
                        try:
                            comment_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[2]/button')
                            comment_button.click()
                        except:
                            pass
                        try:
                            comment_box=webdriver.find_elements_by_tag_name('textarea')
                            comment_box[0].send_keys(str(comment))
                        except:
                            try:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                            except:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                        print("SendKeys successful")
                        file_commented.write(str(lead)+" : "+str(comment)+" : "+str(each_like)+"\n")
                        sleep(randint(2,4))
                        # Enter to post comment
                        #comment_box.send_keys(Keys.ENTER)
                        send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
                        print("SEnd buttonfind successful")
                        send_button.click()
                        print("SEnd buttonclick successful")
                        file1.write(str(lead)+" Commented "+str(comment)+" \n")
                        print(str(lead)+" Commented "+str(comment)+" \n")
                        sleep(1)
                except:
                    print("Commenting Failed!")
                    file1.write(str(lead)+" Commenting Failed - "+str(each_like)+" \n"+str(comment)+" \n\n")
                    tb_message=traceback.format_exc()
                    file1.write(" Full Traceback- "+str(tb_message)+" \n")
                    pass
    except:
        print("Failed liking/commenting!")
        file1.write(" Failed liking/commenting! \n\n")
        tb_message=traceback.format_exc()
        file1.write(" Full Traceback- "+str(tb_message)+" \n")
        continue
# Out:
# Looping runs :  1
#
# Current Post :  https://www.instagram.com/p/CCWJGFmpPCk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  2
#
# Current Post :  https://www.instagram.com/p/BFknKGzR3pt/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  3
#
# Current Post :  https://www.instagram.com/p/BSoOAJOhhYI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  4
#
# Current Post :  https://www.instagram.com/p/BwZ9WQ7B9hr/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  5
#
# Current Post :  https://www.instagram.com/p/BFjnOFHMJ5B/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  6
#
# Current Post :  https://www.instagram.com/p/BLea93xBxIz/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  7
#
# Current Post :  https://www.instagram.com/p/BL7rA55B2RF/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  8
#
# Current Post :  https://www.instagram.com/p/5ArK5oCWzQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  9
#
# Current Post :  https://www.instagram.com/p/5U5OqYiW23/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  10
#
# Current Post :  https://www.instagram.com/p/CCOchEUH9FJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  11
#
# Current Post :  https://www.instagram.com/p/CCJfO44JKnK/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  12
#
# Current Post :  https://www.instagram.com/p/CBx9I4dlkJ0/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  13
#
# Current Post :  https://www.instagram.com/p/CBLCcb6BPAG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  14
#
# Current Post :  https://www.instagram.com/p/CAqf1ESHADW/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  15
#
# Current Post :  https://www.instagram.com/p/CANzFslJ596/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  16
#
# Current Post :  https://www.instagram.com/p/B_wFZEfjDBx/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  17
#
# Current Post :  https://www.instagram.com/p/B_Wo-yOpNv2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  18
#
# Current Post :  https://www.instagram.com/p/B-pgkEJHCWq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  19
#
# Current Post :  https://www.instagram.com/p/B8h76iOnscL/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  20
#
# Current Post :  https://www.instagram.com/p/B52_jWenxfM/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  21
#
# Current Post :  https://www.instagram.com/p/B4LB9KXJKCh/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  22
#
# Current Post :  https://www.instagram.com/p/B1vjLQTnZ8Z/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  23
#
# Current Post :  https://www.instagram.com/p/B1o5SypH1AJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  24
#
# Current Post :  https://www.instagram.com/p/B1aAenFnuAp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  25
#
# Current Post :  https://www.instagram.com/p/B1HzOsMnPbq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  26
#
# Current Post :  https://www.instagram.com/p/B0quQnbHTDI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  27
#
# Current Post :  https://www.instagram.com/p/B0mLgwTHUQN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  28
#
# Current Post :  https://www.instagram.com/p/B0jpfjOnsEd/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  29
#
# Current Post :  https://www.instagram.com/p/B0dwegwnA76/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  30
#
# Current Post :  https://www.instagram.com/p/B0JJuWKnwSp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  31
#
# Current Post :  https://www.instagram.com/p/B0JErN1nyyO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  32
#
# Current Post :  https://www.instagram.com/p/B0EvLvqnnBy/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  33
#
# Current Post :  https://www.instagram.com/p/B0BHzm1HMjH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  34
#
# Current Post :  https://www.instagram.com/p/Bz-rwzbHhVn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  35
#
# Current Post :  https://www.instagram.com/p/Bzq_vlAn_K9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  36
#
# Current Post :  https://www.instagram.com/p/BzfHGkInkvM/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  37
#
# Current Post :  https://www.instagram.com/p/BzRBqrqnf8W/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  38
#
# Current Post :  https://www.instagram.com/p/BzPlf3gHoKm/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  39
#
# Current Post :  https://www.instagram.com/p/BzGxt9Cghjq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  40
#
# Current Post :  https://www.instagram.com/p/BzFozAgHECR/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  41
#
# Current Post :  https://www.instagram.com/p/By07bIQHWLt/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  42
#
# Current Post :  https://www.instagram.com/p/Byi4C_qHduQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  43
#
# Current Post :  https://www.instagram.com/p/ByXnGeRHgFQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  44
#
# Current Post :  https://www.instagram.com/p/ByUSqb6nReb/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  45
#
# Current Post :  https://www.instagram.com/p/ByPSESlHyr3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  46
#
# Current Post :  https://www.instagram.com/p/ByME5FNB_0D/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  47
#
# Current Post :  https://www.instagram.com/p/ByDh-jJH_JL/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  48
#
# Current Post :  https://www.instagram.com/p/BxrBVktFBC2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  49
#
# Current Post :  https://www.instagram.com/p/BxqgJ6AniWD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  50
#
# Current Post :  https://www.instagram.com/p/BxpWj4YHNQH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  51
#
# Current Post :  https://www.instagram.com/p/BxnsWlQHjbD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  52
#
# Current Post :  https://www.instagram.com/p/BxhA2z1Fw5_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  53
#
# Current Post :  https://www.instagram.com/p/BxbSVyJlFOz/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  54
#
# Current Post :  https://www.instagram.com/p/BxZ0W6GHtTp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  55
#
# Current Post :  https://www.instagram.com/p/BxP_VpPhXu3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  56
#
# Current Post :  https://www.instagram.com/p/BxAT0q4Hpnp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  57
#
# Current Post :  https://www.instagram.com/p/Bw7eKEQHujF/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  58
#
# Current Post :  https://www.instagram.com/p/Bw4gLu_n8e7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  59
#
# Current Post :  https://www.instagram.com/p/Bwp31Utnz_c/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  60
#
# Current Post :  https://www.instagram.com/p/Bwluc1klV9o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  61
#
# Current Post :  https://www.instagram.com/p/BwhbIZuHyvk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  62
#
# Current Post :  https://www.instagram.com/p/BwLtWX3BUa2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  63
#
# Current Post :  https://www.instagram.com/p/BwGc1OCFibN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  64
#
# Current Post :  https://www.instagram.com/p/Bv-gy5yBUBw/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  65
#
# Current Post :  https://www.instagram.com/p/BvnDyLZBicu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  66
#
# Current Post :  https://www.instagram.com/p/BvmfSpHh26L/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  67
#
# Current Post :  https://www.instagram.com/p/Bvjohq9Bftg/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  68
#
# Current Post :  https://www.instagram.com/p/BviftUsn0fa/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  69
#
# Current Post :  https://www.instagram.com/p/BvhU-hVh-Us/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  70
#
# Current Post :  https://www.instagram.com/p/Bve45QznCZB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  71
#
# Current Post :  https://www.instagram.com/p/BvaB4jgluPk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  72
#
# Current Post :  https://www.instagram.com/p/BvZpYskBTuY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  73
#
# Current Post :  https://www.instagram.com/p/BvVTc_XBdB3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  74
#
# Current Post :  https://www.instagram.com/p/BvO9h4whlB2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  75
#
# Current Post :  https://www.instagram.com/p/BvKqpXRB2iu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  76
#
# Current Post :  https://www.instagram.com/p/BuRWyybBtV3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  77
#
# Current Post :  https://www.instagram.com/p/BuMDzXZBrgB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  78
#
# Current Post :  https://www.instagram.com/p/BuEe7hgnFkp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  79
#
# Current Post :  https://www.instagram.com/p/Bt9z_yJBGab/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  80
#
# Current Post :  https://www.instagram.com/p/Bt117NNh1Ys/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  81
#
# Current Post :  https://www.instagram.com/p/BtwjOojBKn6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  82
#
# Current Post :  https://www.instagram.com/p/Btu4aDlgsY6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  83
#
# Current Post :  https://www.instagram.com/p/BtoG56khv8T/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  84
#
# Current Post :  https://www.instagram.com/p/Btl1qT7hY8e/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  85
#
# Current Post :  https://www.instagram.com/p/BtjPGJzhq3Y/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  86
#
# Current Post :  https://www.instagram.com/p/BtehrGXhUkV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  87
#
# Current Post :  https://www.instagram.com/p/BtRlqgrh4Wp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  88
#
# Current Post :  https://www.instagram.com/p/BtOrupqhK1j/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  89
#
# Current Post :  https://www.instagram.com/p/BsoXfQdA8Tq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  90
#
# Current Post :  https://www.instagram.com/p/BsnOCRblob5/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  91
#
# Current Post :  https://www.instagram.com/p/BsgvHhyHisi/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  92
#
# Current Post :  https://www.instagram.com/p/BsGSMo5AXrA/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  93
#
# Current Post :  https://www.instagram.com/p/BsBpD5pgRLn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  94
#
# Current Post :  https://www.instagram.com/p/Br-3BI0gTf7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  95
#
# Current Post :  https://www.instagram.com/p/Br70Fn6gjal/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  96
#
# Current Post :  https://www.instagram.com/p/Br0KbiQgTRn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  97
#
# Current Post :  https://www.instagram.com/p/BrgxmBzA9pa/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  98
#
# Current Post :  https://www.instagram.com/p/BrdpQhugKZd/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  99
#
# Current Post :  https://www.instagram.com/p/BrdHL-wgYUT/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  100
#
# Current Post :  https://www.instagram.com/p/BrYYGKsgJRf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  101
#
# Current Post :  https://www.instagram.com/p/BrSqVUkF5Pq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  102
#
# Current Post :  https://www.instagram.com/p/BrQHxQGg0ai/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  103
#
# Current Post :  https://www.instagram.com/p/Bq-IQzWnp_D/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  104
#
# Current Post :  https://www.instagram.com/p/BqgIS72gvS0/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  105
#
# Current Post :  https://www.instagram.com/p/BqfqClRgZDb/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  106
#
# Current Post :  https://www.instagram.com/p/BqQUvXDgauC/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  107
#
# Current Post :  https://www.instagram.com/p/BqCVSowHnBN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  108
#
# Current Post :  https://www.instagram.com/p/BpvSJsdg--x/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  109
#
# Current Post :  https://www.instagram.com/p/BppQyQtATfN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  110
#
# Current Post :  https://www.instagram.com/p/BpmzOycAAmv/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  111
#
# Current Post :  https://www.instagram.com/p/BpiVKXUA7BU/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  112
#
# Current Post :  https://www.instagram.com/p/BpPV2A-hgUY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  113
#
# Current Post :  https://www.instagram.com/p/BpH2Hx4BFTG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  114
#
# Current Post :  https://www.instagram.com/p/BpGeFtIAlKt/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  115
#
# Current Post :  https://www.instagram.com/p/BpFWmKIgT5o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  116
#
# Current Post :  https://www.instagram.com/p/Bo10RE0gmHM/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  117
#
# Current Post :  https://www.instagram.com/p/BopJfGjHmP3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  118
#
# Current Post :  https://www.instagram.com/p/Boj1K5og8BN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  119
#
# Current Post :  https://www.instagram.com/p/BoHTYHyANki/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  120
#
# Current Post :  https://www.instagram.com/p/Bn-HT-OgnoQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  121
#
# Current Post :  https://www.instagram.com/p/Bm856Bbghhu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  122
#
# Current Post :  https://www.instagram.com/p/Bl3mEYMhdQn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  123
#
# Current Post :  https://www.instagram.com/p/Bls1V9tAQg4/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  124
#
# Current Post :  https://www.instagram.com/p/BlqODA9AJa5/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  125
#
# Current Post :  https://www.instagram.com/p/Bk01yLpAgl-/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  126
#
# Current Post :  https://www.instagram.com/p/BklgfCXH7TB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  127
#
# Current Post :  https://www.instagram.com/p/BkgaLGSg32C/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  128
#
# Current Post :  https://www.instagram.com/p/BkOVcUdHtZQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  129
#
# Current Post :  https://www.instagram.com/p/Bj8gAc-glIY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  130
#
# Current Post :  https://www.instagram.com/p/BjZ99I1A0Ji/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  131
#
# Current Post :  https://www.instagram.com/p/BjI3eocgWb0/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  132
#
# Current Post :  https://www.instagram.com/p/BjFb2MxHKOl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  133
#
# Current Post :  https://www.instagram.com/p/Bis1QNrgjqm/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  134
#
# Current Post :  https://www.instagram.com/p/Bifd8GrgbuM/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  135
#
# Current Post :  https://www.instagram.com/p/BiaUpjAgefH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  136
#
# Current Post :  https://www.instagram.com/p/BiHcjdGnNQX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  137
#
# Current Post :  https://www.instagram.com/p/BhyyvxvgqJJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  138
#
# Current Post :  https://www.instagram.com/p/BhmsrweghRG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  139
#
# Current Post :  https://www.instagram.com/p/Bhc8xHcAcmV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  140
#
# Current Post :  https://www.instagram.com/p/BhA0-uylayN/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  141
#
# Current Post :  https://www.instagram.com/p/Bg9K0FEAyLl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  142
#
# Current Post :  https://www.instagram.com/p/Bg7BhQtlyJY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  143
#
# Current Post :  https://www.instagram.com/p/Bg6p4LgheQr/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  144
#
# Current Post :  https://www.instagram.com/p/Bg6oMtKh2cw/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  145
#
# Current Post :  https://www.instagram.com/p/Bg6nnEZBpyd/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  146
#
# Current Post :  https://www.instagram.com/p/Bg14oUWgY9t/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  147
#
# Current Post :  https://www.instagram.com/p/Bg1eA7-AQIb/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  148
#
# Current Post :  https://www.instagram.com/p/Bgzi-NrAsD-/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  149
#
# Current Post :  https://www.instagram.com/p/BgxTcReFW_4/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  150
#
# Current Post :  https://www.instagram.com/p/Bgo-s2LB9ZH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  151
#
# Current Post :  https://www.instagram.com/p/Bgm4COWlY2t/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  152
#
# Current Post :  https://www.instagram.com/p/BgKNhuEFHFP/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  153
#
# Current Post :  https://www.instagram.com/p/BftdXFxAjya/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  154
#
# Current Post :  https://www.instagram.com/p/Bfdh2zYA9lD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  155
#
# Current Post :  https://www.instagram.com/p/BfYyrWdg822/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  156
#
# Current Post :  https://www.instagram.com/p/BfCYbUSAn-X/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  157
#
# Current Post :  https://www.instagram.com/p/BfBr6VuH38e/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  158
#
# Current Post :  https://www.instagram.com/p/BfBV_RXHq7k/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  159
#
# Current Post :  https://www.instagram.com/p/Be_HLAbg-GD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  160
#
# Current Post :  https://www.instagram.com/p/Be6w8awAOSg/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  161
#
# Current Post :  https://www.instagram.com/p/Be1E62qnsse/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  162
#
# Current Post :  https://www.instagram.com/p/BevX_ptAD9r/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  163
#
# Current Post :  https://www.instagram.com/p/BemFfq9Azwb/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  164
#
# Current Post :  https://www.instagram.com/p/Bed_EmWg8tH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  165
#
# Current Post :  https://www.instagram.com/p/BebNOMIAALC/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  166
#
# Current Post :  https://www.instagram.com/p/BeRtIvuAqEJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  167
#
# Current Post :  https://www.instagram.com/p/BeJrQYng0zq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  168
#
# Current Post :  https://www.instagram.com/p/BeEfssnFQIy/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  169
#
# Current Post :  https://www.instagram.com/p/BeCOdvXhI46/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  170
#
# Current Post :  https://www.instagram.com/p/Bdyj2FBA_tW/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  171
#
# Current Post :  https://www.instagram.com/p/BdxzRbFA3Wo/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  172
#
# Current Post :  https://www.instagram.com/p/BdvQGp9AGIE/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  173
#
# Current Post :  https://www.instagram.com/p/BdqOKrqAUzE/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  174
#
# Current Post :  https://www.instagram.com/p/BdkiyHcHfjJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  175
#
# Current Post :  https://www.instagram.com/p/BdQ5o2cgE5m/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  176
#
# Current Post :  https://www.instagram.com/p/BdODRG6gGtT/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  177
#
# Current Post :  https://www.instagram.com/p/BdIVibYATf_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  178
#
# Current Post :  https://www.instagram.com/p/Bc_OCCoFw8g/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  179
#
# Current Post :  https://www.instagram.com/p/BcxwgM6AUFG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  180
#
# Current Post :  https://www.instagram.com/p/BcjIGe_A4EH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  181
#
# Current Post :  https://www.instagram.com/p/BcXaNH2gRVv/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  182
#
# Current Post :  https://www.instagram.com/p/BcKhyGYgKPP/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  183
#
# Current Post :  https://www.instagram.com/p/BcIXYxxgBgx/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  184
#
# Current Post :  https://www.instagram.com/p/BcD2j5FAhps/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  185
#
# Current Post :  https://www.instagram.com/p/BbzSd0WhKH6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  186
#
# Current Post :  https://www.instagram.com/p/BbsQA5BgPPx/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  187
#
# Current Post :  https://www.instagram.com/p/BbnqkK5Awoj/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  188
#
# Current Post :  https://www.instagram.com/p/BbhXYyrAjiL/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  189
#
# Current Post :  https://www.instagram.com/p/BbYGgkOHM8M/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  190
#
# Current Post :  https://www.instagram.com/p/BbDse88jk6S/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  191
#
# Current Post :  https://www.instagram.com/p/BawsRlmjEkO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  192
#
# Current Post :  https://www.instagram.com/p/BakMZ7rFY0h/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  193
#
# Current Post :  https://www.instagram.com/p/Baf_xtHFCG_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  194
#
# Current Post :  https://www.instagram.com/p/BaWk1kin0iO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  195
#
# Current Post :  https://www.instagram.com/p/BZRr2HMFp96/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  196
#
# Current Post :  https://www.instagram.com/p/BYwCMvNAslo/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  197
#
# Current Post :  https://www.instagram.com/p/BYj7-SOle33/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  198
#
# Current Post :  https://www.instagram.com/p/BYg-jXJgRuq/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  199
#
# Current Post :  https://www.instagram.com/p/BYesimslYkc/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  200
#
# Current Post :  https://www.instagram.com/p/BYUdO-qlGRl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  201
#
# Current Post :  https://www.instagram.com/p/BYCuGUylaUX/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  202
#
# Current Post :  https://www.instagram.com/p/BYBTlkOjj9I/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  203
#
# Current Post :  https://www.instagram.com/p/BX12LJrFcne/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  204
#
# Current Post :  https://www.instagram.com/p/BXgdrF1DZj8/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  205
#
# Current Post :  https://www.instagram.com/p/BXgdAriDxrf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  206
#
# Current Post :  https://www.instagram.com/p/BXJat-2lADI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  207
#
# Current Post :  https://www.instagram.com/p/BW5rfMnjwnp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  208
#
# Current Post :  https://www.instagram.com/p/BWnfgnMl50y/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  209
#
# Current Post :  https://www.instagram.com/p/BWlwqugDqyI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  210
#
# Current Post :  https://www.instagram.com/p/BWluSnhDsiC/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  211
#
# Current Post :  https://www.instagram.com/p/BWg1UClF8B5/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  212
#
# Current Post :  https://www.instagram.com/p/BWbuj4tjU3C/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  213
#
# Current Post :  https://www.instagram.com/p/BWaqT16D6PY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  214
#
# Current Post :  https://www.instagram.com/p/BV-54z5F-zX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  215
#
# Current Post :  https://www.instagram.com/p/BV0rBr3lvA8/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  216
#
# Current Post :  https://www.instagram.com/p/BVx9XLKluFS/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  217
#
# Current Post :  https://www.instagram.com/p/BVf4eX9jUCs/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  218
#
# Current Post :  https://www.instagram.com/p/BVcUECKjUfj/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  219
#
# Current Post :  https://www.instagram.com/p/BVVpRqZDRcX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  220
#
# Current Post :  https://www.instagram.com/p/BVVB_8bjdyw/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  221
#
# Current Post :  https://www.instagram.com/p/BVRHGV0lohl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  222
#
# Current Post :  https://www.instagram.com/p/BVP2mEijgj_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  223
#
# Current Post :  https://www.instagram.com/p/BVGIwH5jMv1/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  224
#
# Current Post :  https://www.instagram.com/p/BUiL2OCjGGX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  225
#
# Current Post :  https://www.instagram.com/p/BUAJLhUDbtK/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  226
#
# Current Post :  https://www.instagram.com/p/BT7k7G_DbzG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  227
#
# Current Post :  https://www.instagram.com/p/BTZxCLbADX9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  228
#
# Current Post :  https://www.instagram.com/p/BTXc0xYDI14/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  229
#
# Current Post :  https://www.instagram.com/p/BTKj4cBjOjc/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  230
#
# Current Post :  https://www.instagram.com/p/BTFb7_JDZ1F/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  231
#
# Current Post :  https://www.instagram.com/p/BTC3Efpj-I2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  232
#
# Current Post :  https://www.instagram.com/p/BS3lcLADgrY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  233
#
# Current Post :  https://www.instagram.com/p/BS0_ZtrgVAW/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  234
#
# Current Post :  https://www.instagram.com/p/BSNCowsDXEk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  235
#
# Current Post :  https://www.instagram.com/p/BRMhFUbDyl8/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  236
#
# Current Post :  https://www.instagram.com/p/BQlVmRWDv-x/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  237
#
# Current Post :  https://www.instagram.com/p/BQY14pijrJf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  238
#
# Current Post :  https://www.instagram.com/p/BQV7HorD0a6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  239
#
# Current Post :  https://www.instagram.com/p/BQO0M5gDXkl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  240
#
# Current Post :  https://www.instagram.com/p/BQHaFMtAdgL/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  241
#
# Current Post :  https://www.instagram.com/p/BP-j4VKACC7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  242
#
# Current Post :  https://www.instagram.com/p/BP8CeHzDE-k/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  243
#
# Current Post :  https://www.instagram.com/p/BPvKfKdjj-Q/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  244
#
# Current Post :  https://www.instagram.com/p/BPilSUijLsw/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  245
#
# Current Post :  https://www.instagram.com/p/BPWSuCAhPqA/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  246
#
# Current Post :  https://www.instagram.com/p/BPRC5f2AYS2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  247
#
# Current Post :  https://www.instagram.com/p/BO4v2LiDYRC/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  248
#
# Current Post :  https://www.instagram.com/p/BO2W480j39f/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  249
#
# Current Post :  https://www.instagram.com/p/BOgDffahbWJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  250
#
# Current Post :  https://www.instagram.com/p/BOarC1gD3Ol/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  251
#
# Current Post :  https://www.instagram.com/p/BNzT2LmjDGQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  252
#
# Current Post :  https://www.instagram.com/p/BNmxoq1D1OX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  253
#
# Current Post :  https://www.instagram.com/p/BNM5dS7AaCk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  254
#
# Current Post :  https://www.instagram.com/p/BNM0Aojg36f/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  255
#
# Current Post :  https://www.instagram.com/p/BNAcYDRjpKn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  256
#
# Current Post :  https://www.instagram.com/p/BM-KVAHDbnn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  257
#
# Current Post :  https://www.instagram.com/p/BM2pnLlDfcO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  258
#
# Current Post :  https://www.instagram.com/p/BMhBXT7DxTJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  259
#
# Current Post :  https://www.instagram.com/p/BMN0fMPgM6V/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  260
#
# Current Post :  https://www.instagram.com/p/BL2Zym0Bwi7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  261
#
# Current Post :  https://www.instagram.com/p/BLzWJwmjnk5/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  262
#
# Current Post :  https://www.instagram.com/p/BLwADWxDj8U/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  263
#
# Current Post :  https://www.instagram.com/p/BLm4QAfhrzV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  264
#
# Current Post :  https://www.instagram.com/p/BLW2IfADnOo/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  265
#
# Current Post :  https://www.instagram.com/p/BLUSEq7DE0m/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  266
#
# Current Post :  https://www.instagram.com/p/BKDsykMjCRK/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  267
#
# Current Post :  https://www.instagram.com/p/BJojlX0Bh9R/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  268
#
# Current Post :  https://www.instagram.com/p/BJV4AigjSMA/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  269
#
# Current Post :  https://www.instagram.com/p/BJT4QXRjeBJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  270
#
# Current Post :  https://www.instagram.com/p/BJO0S6-DHyB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  271
#
# Current Post :  https://www.instagram.com/p/BJN-lZZDKmi/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  272
#
# Current Post :  https://www.instagram.com/p/BJGHjIjA0IO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  273
#
# Current Post :  https://www.instagram.com/p/BJEjG_Ehi0r/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  274
#
# Current Post :  https://www.instagram.com/p/BILyvknD5xI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  275
#
# Current Post :  https://www.instagram.com/p/BGX1xa4MJFn/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  276
#
# Current Post :  https://www.instagram.com/p/BFkCyHgsJHp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  277
#
# Current Post :  https://www.instagram.com/p/BFbnHXZMJF6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  278
#
# Current Post :  https://www.instagram.com/p/BFRuADFMJLY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  279
#
# Current Post :  https://www.instagram.com/p/BFCxu4RMJLV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  280
#
# Current Post :  https://www.instagram.com/p/BEzWbwjsJE9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  281
#
# Current Post :  https://www.instagram.com/p/BEZeFS7sJGD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  282
#
# Current Post :  https://www.instagram.com/p/BER1a9KMJO6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  283
#
# Current Post :  https://www.instagram.com/p/BEM5F2WsJPr/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  284
#
# Current Post :  https://www.instagram.com/p/BEKeZShMJAE/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  285
#
# Current Post :  https://www.instagram.com/p/BEKeHJvsJPf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  286
#
# Current Post :  https://www.instagram.com/p/BEHZLI9sJOu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  287
#
# Current Post :  https://www.instagram.com/p/BEG9KNNMJFR/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  288
#
# Current Post :  https://www.instagram.com/p/BEG9DOWMJE7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  289
#
# Current Post :  https://www.instagram.com/p/BEG8_G_MJEw/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  290
#
# Current Post :  https://www.instagram.com/p/BEG85-cMJEl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  291
#
# Current Post :  https://www.instagram.com/p/BEG82uEsJEh/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  292
#
# Current Post :  https://www.instagram.com/p/BEG6Gh5sJOY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  293
#
# Current Post :  https://www.instagram.com/p/BEG5_QSMJN9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  294
#
# Current Post :  https://www.instagram.com/p/BEG57ceMJN3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  295
#
# Current Post :  https://www.instagram.com/p/BEG53jQsJNr/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  296
#
# Current Post :  https://www.instagram.com/p/BEG5BfvsJLp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  297
#
# Current Post :  https://www.instagram.com/p/BI5oQu1AFeK/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  298
#
# Current Post :  https://www.instagram.com/p/BI2VfGGAnRZ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  299
#
# Current Post :  https://www.instagram.com/p/BI1SQMtAt3Q/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  300
#
# Current Post :  https://www.instagram.com/p/BIz2vvbgW6_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  301
#
# Current Post :  https://www.instagram.com/p/BIv1UX7DOqu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  302
#
# Current Post :  https://www.instagram.com/p/BIvoPEXgl-J/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  303
#
# Current Post :  https://www.instagram.com/p/BIui1B7gIdu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  304
#
# Current Post :  https://www.instagram.com/p/BIsE-cLAN2n/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  305
#
# Current Post :  https://www.instagram.com/p/BIqths4gf9O/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  306
#
# Current Post :  https://www.instagram.com/p/BIqIEicDSLe/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  307
#
# Current Post :  https://www.instagram.com/p/BIi-oGlAJev/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  308
#
# Current Post :  https://www.instagram.com/p/BIhxyxWgFP6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  309
#
# Current Post :  https://www.instagram.com/p/BId7hQlBbWf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  310
#
# Current Post :  https://www.instagram.com/p/BIc59abA57B/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  311
#
# Current Post :  https://www.instagram.com/p/BIaCAHcgf1A/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  312
#
# Current Post :  https://www.instagram.com/p/BIYEJDoDEwH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  313
#
# Current Post :  https://www.instagram.com/p/BIXi3abAF8e/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  314
#
# Current Post :  https://www.instagram.com/p/BIWBryFAR0x/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  315
#
# Current Post :  https://www.instagram.com/p/BIU_-0GAtrL/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  316
#
# Current Post :  https://www.instagram.com/p/BIQMFV9jRbW/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  317
#
# Current Post :  https://www.instagram.com/p/BH2HNdUAjKe/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  318
#
# Current Post :  https://www.instagram.com/p/BH10x2PjbWQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  319
#
# Current Post :  https://www.instagram.com/p/BHuPqdwA9cI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  320
#
# Current Post :  https://www.instagram.com/p/BEG4xldMJLG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  321
#
# Current Post :  https://www.instagram.com/p/BH1zu8pjATD/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  322
#
# Current Post :  https://www.instagram.com/p/BHyahozj__m/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  323
#
# Current Post :  https://www.instagram.com/p/BHxcyZSDGX-/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  324
#
# Current Post :  https://www.instagram.com/p/BHufRNfDog9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  325
#
# Current Post :  https://www.instagram.com/p/BHU6tWkBtwy/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  326
#
# Current Post :  https://www.instagram.com/p/BGIOenCrluB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  327
#
# Current Post :  https://www.instagram.com/p/BGAXbp-LlvG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  328
#
# Current Post :  https://www.instagram.com/p/BF-OYMDLlp0/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  329
#
# Current Post :  https://www.instagram.com/p/BFbX5TvjLSY/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  330
#
# Current Post :  https://www.instagram.com/p/BFTlk2Ww91s/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  331
#
# Current Post :  https://www.instagram.com/p/BFPNPBWjLdo/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  332
#
# Current Post :  https://www.instagram.com/p/BFM98dpw98a/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  333
#
# Current Post :  https://www.instagram.com/p/BFDEofeh3h6/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  334
#
# Current Post :  https://www.instagram.com/p/BFC6dQ3Q91r/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  335
#
# Current Post :  https://www.instagram.com/p/BFAqAVDw9zY/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  336
#
# Current Post :  https://www.instagram.com/p/BFAYcgLQ9yQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  337
#
# Current Post :  https://www.instagram.com/p/BE_4r1qw9zc/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  338
#
# Current Post :  https://www.instagram.com/p/BE_fFOnw93v/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  339
#
# Current Post :  https://www.instagram.com/p/BE-jK3zQ97m/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  340
#
# Current Post :  https://www.instagram.com/p/BE9Sdk_Q9ww/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  341
#
# Current Post :  https://www.instagram.com/p/BE8tEXPDLZe/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  342
#
# Current Post :  https://www.instagram.com/p/BE7n0kpw93j/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  343
#
# Current Post :  https://www.instagram.com/p/BE1xcjNw9xH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  344
#
# Current Post :  https://www.instagram.com/p/BE1cIKNw90B/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  345
#
# Current Post :  https://www.instagram.com/p/BE05mVjQ96C/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  346
#
# Current Post :  https://www.instagram.com/p/BEz2DESw9wB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  347
#
# Current Post :  https://www.instagram.com/p/BEzdX4TQ9wG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  348
#
# Current Post :  https://www.instagram.com/p/BExAGfoQ9x_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  349
#
# Current Post :  https://www.instagram.com/p/BEwWB04w940/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  350
#
# Current Post :  https://www.instagram.com/p/BEvfQE_DLVX/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  351
#
# Current Post :  https://www.instagram.com/p/BEt_j7Aw96v/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  352
#
# Current Post :  https://www.instagram.com/p/BEtgB8LQ9-_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  353
#
# Current Post :  https://www.instagram.com/p/BEqIfZIjLQc/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  354
#
# Current Post :  https://www.instagram.com/p/BEToVGkw9_o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  355
#
# Current Post :  https://www.instagram.com/p/BESMtM5rlmz/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  356
#
# Current Post :  https://www.instagram.com/p/BENvIhEjLf3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  357
#
# Current Post :  https://www.instagram.com/p/BEMI000w99N/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  358
#
# Current Post :  https://www.instagram.com/p/BEKz_DRG2uV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  359
#
# Current Post :  https://www.instagram.com/p/BEKQWH9w91o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  360
#
# Current Post :  https://www.instagram.com/p/BEJeHvfw93s/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  361
#
# Current Post :  https://www.instagram.com/p/BEH5BDwLlB4/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  362
#
# Current Post :  https://www.instagram.com/p/BEG9g_0jLik/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  363
#
# Current Post :  https://www.instagram.com/p/BEGmTaLQ9xh/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  364
#
# Current Post :  https://www.instagram.com/p/BEE722Rw9_P/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  365
#
# Current Post :  https://www.instagram.com/p/BEEqK0xDLuZ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  366
#
# Current Post :  https://www.instagram.com/p/BEEYsTgw96L/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  367
#
# Current Post :  https://www.instagram.com/p/BECy9SEDLnQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  368
#
# Current Post :  https://www.instagram.com/p/BECGTsiQ92e/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  369
#
# Current Post :  https://www.instagram.com/p/BEB4ZzVLlvx/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  370
#
# Current Post :  https://www.instagram.com/p/BEAJi9dDLgV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  371
#
# Current Post :  https://www.instagram.com/p/BD_uRCkw90s/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  372
#
# Current Post :  https://www.instagram.com/p/BD9HKhCQ96o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  373
#
# Current Post :  https://www.instagram.com/p/BD8zaJ0w9xf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  374
#
# Current Post :  https://www.instagram.com/p/BD8vB1RpQzi/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  375
#
# Current Post :  https://www.instagram.com/p/BD6lZDNw9wE/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  376
#
# Current Post :  https://www.instagram.com/p/BD6PtAPw905/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  377
#
# Current Post :  https://www.instagram.com/p/BD4eJyBw94D/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  378
#
# Current Post :  https://www.instagram.com/p/BD3-jMlw9z3/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  379
#
# Current Post :  https://www.instagram.com/p/BD3nscjw920/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  380
#
# Current Post :  https://www.instagram.com/p/BD3PVv8Q9wu/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  381
#
# Current Post :  https://www.instagram.com/p/BD3GvlJjLQU/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  382
#
# Current Post :  https://www.instagram.com/p/BD2f5HFjLXQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  383
#
# Current Post :  https://www.instagram.com/p/BD1m6pTDLlB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  384
#
# Current Post :  https://www.instagram.com/p/BD1cMB6Q99F/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  385
#
# Current Post :  https://www.instagram.com/p/BD0zQKVQ94A/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  386
#
# Current Post :  https://www.instagram.com/p/BD0GpygDLX_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  387
#
# Current Post :  https://www.instagram.com/p/BDzPfCYQ9y7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  388
#
# Current Post :  https://www.instagram.com/p/BDy9a2zw9zB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  389
#
# Current Post :  https://www.instagram.com/p/BDyT0rOQ95f/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  390
#
# Current Post :  https://www.instagram.com/p/BDw4miDjLkH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  391
#
# Current Post :  https://www.instagram.com/p/BDv67gCw91A/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  392
#
# Current Post :  https://www.instagram.com/p/BDuUtsGw9xV/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  393
#
# Current Post :  https://www.instagram.com/p/BDttOebLlqs/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  394
#
# Current Post :  https://www.instagram.com/p/BDtCXndQ9-1/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  395
#
# Current Post :  https://www.instagram.com/p/BDra-wWw9zi/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  396
#
# Current Post :  https://www.instagram.com/p/BDrAd80w9yB/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  397
#
# Current Post :  https://www.instagram.com/p/BDqhvW9Q99v/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  398
#
# Current Post :  https://www.instagram.com/p/BDp2ICuhrsK/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  399
#
# Current Post :  https://www.instagram.com/p/BDo4ansQ95q/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  400
#
# Current Post :  https://www.instagram.com/p/BDoQ6R8Q981/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  401
#
# Current Post :  https://www.instagram.com/p/BDn9NJlw9wv/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  402
#
# Current Post :  https://www.instagram.com/p/BDmme45Q9-a/
#
# Counter Value : 0
# Failed liking/commenting!
# Looping runs :  403
#
# Current Post :  https://www.instagram.com/p/BDmWXBKw9x_/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  404
#
# Current Post :  https://www.instagram.com/p/BDmG4wkQ93l/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  405
#
# Current Post :  https://www.instagram.com/p/BDlpzykw99k/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  406
#
# Current Post :  https://www.instagram.com/p/BDlUs_cw9_m/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  407
#
# Current Post :  https://www.instagram.com/p/BDk9dpAjLUk/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  408
#
# Current Post :  https://www.instagram.com/p/BDkh2JxDLcM/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  409
#
# Current Post :  https://www.instagram.com/p/BDji7tqQ974/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  410
#
# Current Post :  https://www.instagram.com/p/BDjcbt_jLph/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  411
#
# Current Post :  https://www.instagram.com/p/BDisiVIQ95u/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  412
#
# Current Post :  https://www.instagram.com/p/BDgX6abQ92Y/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  413
#
# Current Post :  https://www.instagram.com/p/BDfIKRcQ9y-/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  414
#
# Current Post :  https://www.instagram.com/p/BDeuOThDLjp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  415
#
# Current Post :  https://www.instagram.com/p/BDYk_GGw90G/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  416
#
# Current Post :  https://www.instagram.com/p/BDWJCyvtIls/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  417
#
# Current Post :  https://www.instagram.com/p/BDV9G3UQ97K/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  418
#
# Current Post :  https://www.instagram.com/p/BDTzYsgw95b/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  419
#
# Current Post :  https://www.instagram.com/p/BDTYhQjw99J/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  420
#
# Current Post :  https://www.instagram.com/p/BDRGju1Q97P/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  421
#
# Current Post :  https://www.instagram.com/p/BDPQl-1MgGp/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  422
#
# Current Post :  https://www.instagram.com/p/BDOZKehw96W/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  423
#
# Current Post :  https://www.instagram.com/p/BDN8FSljLfG/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  424
#
# Current Post :  https://www.instagram.com/p/BDN1Xc3DLqS/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  425
#
# Current Post :  https://www.instagram.com/p/BDMllhuw9zH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  426
#
# Current Post :  https://www.instagram.com/p/BDMRyZWw95c/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  427
#
# Current Post :  https://www.instagram.com/p/BDMDmukw94e/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  428
#
# Current Post :  https://www.instagram.com/p/BDLqz46Q9yQ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  429
#
# Current Post :  https://www.instagram.com/p/BDKNeB9w9xf/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  430
#
# Current Post :  https://www.instagram.com/p/BDJz2XpDLrO/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  431
#
# Current Post :  https://www.instagram.com/p/BDJHlCwDLuH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  432
#
# Current Post :  https://www.instagram.com/p/BDI_fgLQ90A/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  433
#
# Current Post :  https://www.instagram.com/p/BDHwoIvjLst/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  434
#
# Current Post :  https://www.instagram.com/p/BDHfDWvQ90S/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  435
#
# Current Post :  https://www.instagram.com/p/BDGNgYSw96A/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  436
#
# Current Post :  https://www.instagram.com/p/BDFBEgvDLjI/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  437
#
# Current Post :  https://www.instagram.com/p/BDE22SqQ9xx/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  438
#
# Current Post :  https://www.instagram.com/p/BDD9WFFw99g/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  439
#
# Current Post :  https://www.instagram.com/p/BDCQkgxJSMJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  440
#
# Current Post :  https://www.instagram.com/p/BDBbvcXw9y7/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  441
#
# Current Post :  https://www.instagram.com/p/BC-44gmw92M/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  442
#
# Current Post :  https://www.instagram.com/p/BC94cbPDLS2/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  443
#
# Current Post :  https://www.instagram.com/p/BC6hWk5Q94o/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  444
#
# Current Post :  https://www.instagram.com/p/BC4V4Low91a/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  445
#
# Current Post :  https://www.instagram.com/p/BC170c4Llui/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  446
#
# Current Post :  https://www.instagram.com/p/BC1U0t6Q98X/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  447
#
# Current Post :  https://www.instagram.com/p/BC0chB9w93S/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  448
#
# Current Post :  https://www.instagram.com/p/BCyvp0dQ92X/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  449
#
# Current Post :  https://www.instagram.com/p/BCx4FJkw99Q/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  450
#
# Current Post :  https://www.instagram.com/p/BCw66kgw98E/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  451
#
# Current Post :  https://www.instagram.com/p/BCwKy8Iw9yH/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  452
#
# Current Post :  https://www.instagram.com/p/BCszDHrw949/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  453
#
# Current Post :  https://www.instagram.com/p/BCswAgnjLU9/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  454
#
# Current Post :  https://www.instagram.com/p/BCqeHq3w98Z/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  455
#
# Current Post :  https://www.instagram.com/p/BCqK7EqQ9wl/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  456
#
# Current Post :  https://www.instagram.com/p/BCntyRTsAnJ/
#
# Counter Value : 0
#
# Failed liking/commenting!
# Looping runs :  457
#
# Current Post :  https://www.instagram.com/p/BCnnjO_w933/
#
# Counter Value : 0

# %%
import winsound
frequency = 2500  # Set Frequency To 2500 Hertz
duration = 5000  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)

# %%
#for fashion and other stuff
#do the main thing
hashtag_posts=posts
counter=0
big_count=0

for post in hashtag_posts:
    big_count+=1
    print(big_count)
    try:
        if post in visited_posts:
            continue

        visited_posts.append(post)
        file3.write(str(post)+"\n")
        #{loop post_tag open
        print("\nCurrent Post : ",post)
        file1.write("\nCurrent Post : "+str(post)+"\n")
        #limit too many interactions
        file1.write("\nCounter Value : "+str(counter)+"\n")
        print("\nCounter Value : "+str(counter)+"\n")
        
        file1.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file1.fileno())
        file2.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file2.fileno())
        file3.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file3.fileno())
        file_users.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_users.fileno())
        file_messaged.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_messaged.fileno())
        file_commented.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_commented.fileno())
        file_liked.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file_liked.fileno())
        
        if(counter>=40):
            print("User activity max reached!!")
            file1.write("\nUser activity max reached!!\n")
            file1.close()
            file2.close()
            file_users.close()
            file_messaged.close()
            file_commented.close()
            file_liked.close()
            break  
        webdriver.get(post)
        sleep(randint(6,9))

        #link of id
        goto_ids=[ '/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/div[2]/div[1]/ul/div/li/div/div/div[2]/h2/div/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/header/div[2]/div[1]/div[1]/a']
        #access the id link
        for idx in goto_ids:
            try:
                goto_id=webdriver.find_element_by_xpath(idx)
                break
            except:
                continue

        lead=goto_id.text
        print("Current User: ",lead)
        file1.write("Current User: "+str(lead)+"\n")
        if lead in visited_users:
            continue

        visited_users.append(lead)
        file2.write(str(lead)+"\n")
        goto_id.click()
        sleep(randint(2,6))
        

        #get followers and following
        try:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
            followers=get_int(followers_element.text)
        except:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/ul/li[2]/a/span')
            followers=get_int(followers_element.text)

        print("Followers :",followers)
        sleep(randint(4,10))
        file1.write("Followers :"+str(followers)+"\n")

        try:
            following_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
        except:
            #followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
            print("Err")

        following=get_int(following_element.text)
        print("Following :",following)
        file1.write("Following :"+str(following)+"\n")
        sleep(randint(4,10))


        if((following>followers) or (followers<300)):
            #{user loop open
            print("Found user!!!!")
            file1.write("Found user!!!!"+"\n")
            try:
                #follow_probability=randint(1,10)
                follow_probability=1
                if (follow_probability<=2):
                    follow_button = webdriver.find_element_by_xpath('//button[text()="Follow"]')
                    follow_button.click()
                    sleep(randint(5,10))
                    file1.write(str(lead)+" Followed \n")
                    file_users.write(str(lead)+" \n")
            except:
                #file1.write(lead+" Error Following \n")
                print(str(lead)+" Error Following \n")
                file1.write(str(lead)+" Error Following \n")
                pass
            sleep(randint(4,7))

            #then do the liking and commenting and messaging (if possible)
            #messaging
            try:
                # Comments and tracker
                messages=[' https://www.instagram.com/p/B_VDVyBp08G/ \n Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B-ZeWRwJuZR/ \n Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8E0ChNpPWi/ \n Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8yRJUVpW98/ \n Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          ' https://www.instagram.com/p/B8yKLJYJGO3/ \n Do support the post with your valuable likes. Do check out my handle if you enjoyed my posts! Your support is indeed very amazing. Thanks ❤️!',
                          " https://www.instagram.com/p/B_VDVyBp08G/ \nHi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B-ZeWRwJuZR/ \n Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B8E0ChNpPWi/ \nHi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B8yRJUVpW98/ \nHi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          "https://www.instagram.com/p/B_VDVyBp08G/Hi friends, I'm just starting as an influencer! Do support with your highly valuable likes! Your support has always been motivating! THANKS ❤️🖤. ",
                          ' https://www.instagram.com/p/B_VDVyBp08G/ \nHello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/ \n Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ \nHello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B8yRJUVpW98/ \nHello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hello guys, Im just starting as an influencer and will need support from the community! Do help with your precious likes nd comments! ',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ \nHey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/ \n Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ \nHey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          'https://www.instagram.com/p/B_VDVyBp08G/Hey mate, Im beginning as an influencer and will need support from all of you! Do helpout with your golden engagements!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ \nI really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B-ZeWRwJuZR/ \n I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B8E0ChNpPWi/ \nI really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B8yRJUVpW98/ \nI really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          'https://www.instagram.com/p/B_VDVyBp08G/I really appreciate your awesome profile,dear friend! Do check back mine if you liked my post!',
                          ' https://www.instagram.com/p/B_VDVyBp08G/ \nYour support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B-ZeWRwJuZR/ \n Your support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B8E0ChNpPWi/ \nYour support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B8yRJUVpW98/ \nYour support has always been amazing ! Do give me a thumbs up if you liked my post!',
                         'https://www.instagram.com/p/B_VDVyBp08G/Your support has always been amazing ! Do give me a thumbs up if you liked my post!']
                message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
                message_button.click()
                sleep(randint(3,6))
                message=random.choice(messages)
                
                try:
                    message_box=webdriver.find_elements_by_tag_name('textarea')
                    message_box[0].send_keys(message)
                except:
                    message_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[2]/div/div[2]/div/div/div[2]/textarea')
                    message_box.send_keys(message)
                
                sleep(randint(2,4))
                send_button=webdriver.find_element_by_xpath('//button[text()="Send"]')
                send_button.click()
                file1.write(lead+" Messaged "+message+" \n")
                file_messaged.write(lead+" : Messaged : "+message+" \n")
                messaged_users.append(str(lead)+"||"+str(message))
                sleep(1)
                info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
                info_button.click()
                move_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div/div[2]/div[2]/div[1]/button')
                move_button.click()
                sleep(randint(2,10))
                file1.write(" Moved message \n")
                print("Sent message \n")
            except:
                file1.write(lead+" Messaged Failed "+message+" \n")
                print(lead+" Messaging Failed "+message+" \n")
                pass

            counter+=1

            webdriver.get('https://www.instagram.com/'+ lead + '/')

            #first get all post links of this user
            #best working
            user_posts=[]
            for i in range(5):
                elems = webdriver.find_elements_by_xpath("//a[@href]")
                for elem in elems:
                    post_link=elem.get_attribute("href")
                    #print(post_link)
                    if(re.search("^https://www.instagram.com/p/.", post_link)):
                        if post_link not in user_posts:
                            user_posts.append(post_link)
                webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
                if len(user_posts)>=500:
                    break
                sleep(randint(2,4))
            print("Got user posts!!")
            file1.write(" Got user posts!! \n")
            


            #get posts to be liked recent posts preferred
            #probability play comes here
            length=len(user_posts)
            probabilities = [0] * length
            for i in range(length):
                probabilities[i]=(length-i)/length
            probabilities = np.array(probabilities)
            probabilities /= probabilities.sum()  # normalize
            randomElement = choice(user_posts, p=probabilities)
            max_likes=randint(3,5)
            likes=[]
            for i in range(max_likes):
                randomElement = choice(user_posts, p=probabilities)
                likes.append(randomElement)
            #for each_like in likes:
            #print(user_posts.index(each_like))
            #everything happenning under main user try

            print("Travelled so far")
            #give actual likes and comments
            for each_like in likes:
                #{
                file1.write(lead+" Liking Post - "+str(each_like)+" \n")
                print(str(lead)+" Liking Post - "+str(each_like)+" \n")
                #goto_post=webdriver.get(each_like)
                webdriver.get(each_like)
                sleep(randint(2,4))
                like_buttons=[ '/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button']
                for idx in like_buttons:
                    try:
                        #liketry open
                        like_button=webdriver.find_element_by_xpath(idx)
                        #break
                        #liketry close
                    except:
                        file1.write(str(lead)+" Failed to like!!!- "+str(each_like)+" \n")
                        tb_message=traceback.format_exc()
                        file1.write(" Full Traceback- "+str(tb_message)+" \n")
                        continue
                like_button.click()
                file_liked.write(str(lead)+" : Post Liked : "+str(each_like)+" \n")
                sleep(randint(2,4))
                print(str(lead)+" Post Liked - "+str(each_like)+" \n")
                file1.write(str(lead)+" Post Liked - "+str(each_like)+" \n")
                # Comments and tracker
                comm_prob = randint(1,10)

                #comm_prob=10
                comments=["Hey,I found your profile really mind-blowing! Mind checking back mine?",
                            "Your profile is really amazing,I found your posts the best on Intsagram today! Do check back my profile too!",
                            "I really enjoyed scrolling through your posts! Do like mine if you reciprocate!",
                            "Hey,I found your feed really awesome! One of the very best today!! Do check out my profile too!",
                            "This profile is one of the best things I found on instagram today! #the_best_gallery",
                            "Wow! Your instagram handle is really cool! ",
                            "TBH, I seriously love how expressive your work is. ;D ",
                            "If any pic ever deserved a love react it’s this one!",
                            "I don’t know if you’re aware, but you're gonna be famous pretty soon. #Amazing posts :X",
                            "Your feed is so very aesthetic! I simply enjoyed scrolling through it a lot! :)",
                            "Thats a really dashing picture!:0",
                            "I really like your insta!:p"]
                comment=random.choice(comments)
                print("random comment chosen!")
                #if comment probability>90% then only comment 
                try:
                    if comm_prob > 6:
                        print("CommentBox successful")
                        file1.write(str(lead)+" Trying commenting - "+str(each_like)+" \n")
                        sleep(randint(4,10))
                        
                        try:
                            comment_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[2]/button')
                            comment_button.click()
                        except:
                            pass
                        try:
                            comment_box=webdriver.find_elements_by_tag_name('textarea')
                            comment_box[0].send_keys(str(comment))
                        except:
                            try:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                            except:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                        print("SendKeys successful")
                        file_commented.write(str(lead)+" : "+str(comment)+" : "+str(each_like)+"\n")
                        sleep(randint(2,4))
                        # Enter to post comment
                        #comment_box.send_keys(Keys.ENTER)
                        send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
                        print("SEnd buttonfind successful")
                        send_button.click()
                        print("SEnd buttonclick successful")
                        file1.write(str(lead)+" Commented "+str(comment)+" \n")
                        print(str(lead)+" Commented "+str(comment)+" \n")
                        sleep(1)
                except:
                    print("Commenting Failed!")
                    file1.write(str(lead)+" Commenting Failed - "+str(each_like)+" \n"+str(comment)+" \n\n")
                    tb_message=traceback.format_exc()
                    file1.write(" Full Traceback- "+str(tb_message)+" \n")
                    pass
    except:
        print("Failed liking/commenting!")
        file1.write(" Failed liking/commenting! \n\n")
        tb_message=traceback.format_exc()
        file1.write(" Full Traceback- "+str(tb_message)+" \n")
        continue

# %%
webdriver.quit()

# %%
messages=[' https://www.instagram.com/p/B-ZeWRwJuZR/ \n Do support the post with your valuable likes. . Thanks ❤️.',]
message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
message_button.click()
sleep(randint(3,6))
message=random.choice(messages)
                
try:
    message_box=webdriver.find_elements_by_tag_name('textarea')
    message_box[0].send_keys(message)
except:
    message_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[2]/div/div[2]/div/div/div[2]/textarea')
    message_box.send_keys(message)

# %%
#do the main thing
hashtag_posts=posts
counter=0
for post in hashtag_posts:
    try:
        #{loop post_tag open
        print("\nCurrent Post : ",post)
        file1.write("\nCurrent Post : "+str(post)+"\n")
        #limit too many interactions
        file1.write("\nCounter Value : "+str(counter)+"\n")
        
        file1.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file1.fileno())
        file2.flush()
        # typically the above line would do. however this is used to ensure that the file is written
        os.fsync(file2.fileno())
        
        if(counter>=20):
            print("User activity max reached!!")
            file1.write("\nUser activity max reached!!\n")
            file1.close()
            file2.close()
            break  
        webdriver.get(post)
        sleep(randint(6,9))

        #link of id
        goto_ids=[ '/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/div[2]/div[1]/ul/div/li/div/div/div[2]/h2/div/a',
                    '/html/body/div[1]/section/main/div/div[1]/article/header/div[2]/div[1]/div[1]/a']
        #access the id link
        for idx in goto_ids:
            try:
                goto_id=webdriver.find_element_by_xpath(idx)
                break
            except:
                continue

        lead=goto_id.text
        print("Current User: ",lead)
        file1.write("Current User: "+str(lead)+"\n")
        if lead in visited_users:
            continue

        visited_users.append(lead)
        file2.write(str(lead)+"\n")
        goto_id.click()
        sleep(randint(2,6))
        

        #get followers and following
        try:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
            followers=get_int(followers_element.text)
        except:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/ul/li[2]/a/span')
            followers=get_int(followers_element.text)

        print("Followers :",followers)
        sleep(randint(4,10))
        file1.write("Followers :"+str(followers)+"\n")

        try:
            following_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
        except:
            #followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
            print("Err")

        following=get_int(following_element.text)
        print("Following :",following)
        file1.write("Following :"+str(following)+"\n")
        sleep(randint(4,10))


        if((following>followers) or (followers<300)):
            #{user loop open
            print("Found user!!!!")
            file1.write("Found user!!!!"+"\n")
            try:
                #follow_probability=randint(1,10)
                follow_probability=1
                if (follow_probability<=2):
                    follow_button = webdriver.find_element_by_xpath('//button[text()="Follow"]')
                    follow_button.click()
                    sleep(randint(5,10))
                    file1.write(str(lead)+" Followed \n")
            except:
                #file1.write(lead+" Error Following \n")
                print(str(lead)+" Error Following \n")
                file1.write(str(lead)+" Error Following \n")
                pass
            sleep(randint(4,7))

            #then do the liking and commenting and messaging (if possible)
            #messaging
            try:
                # Comments and tracker
                messages=[' https://www.instagram.com/p/B-ZeWRwJuZR/  Do support the post with your valuable likes. Your appreciation really motivates me to expand my knowledge, develop & explore such softwares from the latest ai tech. All my code is also available on my github profile link. Thanks ❤️.',
                                  'https://www.instagram.com/p/B_NKC5GjSBn/   I work as a small developer to make such models in machine learning! Do support me with your valuable likes!',
                                  'https://www.instagram.com/p/B_NKC5GjSBn/  Do share if you like my posts! I really appreciate your support!',
                                  'https://www.instagram.com/p/B-j1VbYJxzT/ If possible, do give me a thumbs up if you like my post. Such feedback motivates me to develop small softwares like these!',
                                  'https://www.instagram.com/p/B-ZeWRwJuZR/ Do share my posts if you like #deeplearning and the latest ai tech!',
                                  'Hey! Do check out my profile!!! I am a deep learning enthusiast trying to learn models!']
                message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
                message_button.click()
                sleep(randint(3,6))
                message=random.choice(messages)
                
                try:
                    message_box=webdriver.find_elements_by_tag_name('textarea')
                    message_box[0].send_keys(message)
                except:
                    message_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[2]/div/div[2]/div/div/div[2]/textarea')
                    message_box.send_keys(message)
                
                sleep(randint(2,4))
                send_button=webdriver.find_element_by_xpath('//button[text()="Send"]')
                send_button.click()
                file1.write(lead+" Messaged "+message+" \n")
                sleep(1)
                info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
                info_button.click()
                move_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div/div[2]/div[2]/div[1]/button')
                move_button.click()
                sleep(randint(2,10))
                file1.write(" Moved message \n")
                print("Sent message \n")
            except:
                file1.write(lead+" Messaged Failed "+message+" \n")
                print(lead+" Messaging Failed "+message+" \n")
                pass

            counter+=1

            webdriver.get('https://www.instagram.com/'+ lead + '/')

            #first get all post links of this user
            #best working
            user_posts=[]
            for i in range(5):
                elems = webdriver.find_elements_by_xpath("//a[@href]")
                for elem in elems:
                    post_link=elem.get_attribute("href")
                    #print(post_link)
                    if(re.search("^https://www.instagram.com/p/.", post_link)):
                        if post_link not in user_posts:
                            user_posts.append(post_link)
                webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
                if len(user_posts)>=50:
                    break
                sleep(randint(2,4))
            print("Got user posts!!")
            file1.write(" Got user posts!! \n")
            


            #get posts to be liked recent posts preferred
            #probability play comes here
            length=len(user_posts)
            probabilities = [0] * length
            for i in range(length):
                probabilities[i]=(length-i)/length
            probabilities = np.array(probabilities)
            probabilities /= probabilities.sum()  # normalize
            randomElement = choice(user_posts, p=probabilities)
            max_likes=randint(3,6)
            likes=[]
            for i in range(max_likes):
                randomElement = choice(user_posts, p=probabilities)
                likes.append(randomElement)
            #for each_like in likes:
            #print(user_posts.index(each_like))
            #everything happenning under main user try

            print("Travelled so far")
            #give actual likes and comments
            for each_like in likes:
                #{
                file1.write(lead+" Liking Post - "+str(each_like)+" \n")
                print(str(lead)+" Liking Post - "+str(each_like)+" \n")
                #goto_post=webdriver.get(each_like)
                webdriver.get(each_like)
                sleep(randint(2,4))
                like_buttons=[ '/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button',
                              '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button']
                for idx in like_buttons:
                    try:
                        #liketry open
                        like_button=webdriver.find_element_by_xpath(idx)
                        #break
                        #liketry close
                    except:
                        file1.write(str(lead)+" Failed to like!!!- "+str(each_like)+" \n")
                        tb_message=traceback.format_exc()
                        file1.write(" Full Traceback- "+str(tb_message)+" \n")
                        continue
                like_button.click()
                sleep(randint(2,4))
                print(str(lead)+" Post Liked - "+str(each_like)+" \n")
                file1.write(str(lead)+" Post Liked - "+str(each_like)+" \n")
                # Comments and tracker
                comm_prob = randint(1,10)

                #comm_prob=10
                comments=["Hey,I found your ID really cool! Mind checking back mine?",
                            "Hey,I found your posts really awesome! Do checking back my profile too!",
                            "I really enjoyed scrolling through your posts! Do like mine if you reciprocate!",
                            "Hey,I found your feed really awesome! Do check out my profile too!",
                            "Boo yah! I found your posts mind blowing! #Oneofthosefewgalleries",
                            "Yohoo! Your instagram handle is really nice! ",
                            "I love how expressive your work is. ;D ",
                            "If any pic ever deserved a thumbs up it’s this one!",
                            "I don’t know if you’re aware, but you're gonna be famous pretty soon. #GreatPicture :X",
                            "Your feed is so aesthetic! I simply enjoyed it a lot! :)",
                            "Thats a really dashing post!:0",
                            "I really like your insta!:p"]
                comment=random.choice(comments)
                print("random comment chosen!")
                #if comment probability>90% then only comment 
                try:
                    if comm_prob > 8:
                        print("CommentBox successful")
                        file1.write(str(lead)+" Trying commenting - "+str(each_like)+" \n")
                        sleep(randint(4,10))
                        
                        try:
                            comment_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[2]/button')
                            comment_button.click()
                        except:
                            pass
                        try:
                            comment_box=webdriver.find_elements_by_tag_name('textarea')
                            comment_box[0].send_keys(str(comment))
                        except:
                            try:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                            except:
                                comment_box=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[3]/div/form/textarea')
                                comment_box[0].send_keys(str(comment))
                        print("SendKeys successful")
                        sleep(randint(2,4))
                        # Enter to post comment
                        #comment_box.send_keys(Keys.ENTER)
                        send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
                        print("SEnd buttonfind successful")
                        send_button.click()
                        print("SEnd buttonclick successful")
                        file1.write(str(lead)+" Commented "+str(comment)+" \n")
                        print(str(lead)+" Commented "+str(comment)+" \n")
                        sleep(1)
                except:
                    print("Commenting Failed!")
                    file1.write(str(lead)+" Commenting Failed - "+str(each_like)+" \n"+str(comment)+" \n\n")
                    tb_message=traceback.format_exc()
                    file1.write(" Full Traceback- "+str(tb_message)+" \n")
                    pass
    except:
        print("Failed liking/commenting!")
        file1.write(" Failed liking/commenting! \n\n")
        tb_message=traceback.format_exc()
        file1.write(" Full Traceback- "+str(tb_message)+" \n")
        continue

# %%
try:
    comment_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[2]/button')
    comment_button.click()
except:
    pass
comment_box=webdriver.find_elements_by_tag_name('textarea')
print(len(comment_box))
print("CommentBox successful")
sleep(1)
comment_box[0].send_keys(str("comment"))

# %%
#txt.send_keys(Keys.ENTER)

# %%
#do the main thing
hashtag_posts=posts
counter=0
for post in hashtag_posts:
    #loop post_tag open
    try: 
        #main post try
        
        #limit too many interactions
        if(counter>=50):
            print("User activity max reached!!")
            break
            
        
        webdriver.get(post)
        sleep(randint(6,9))
        
        #
        #link of id
        goto_ids=[ '/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                  '/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a',
                  '/html/body/div[1]/section/main/div/div[1]/article/div[2]/div[1]/ul/div/li/div/div/div[2]/h2/div/a',
                  '/html/body/div[1]/section/main/div/div[1]/article/header/div[2]/div[1]/div[1]/a'
                   ]
        #access the id link
        for idx in goto_ids:
            try:
                goto_id=webdriver.find_element_by_xpath(idx)
                break
            except:
                continue
        
        lead=goto_id.text
        print("Current User:",lead)
        
        if lead in visited_users:
            continue
            
        visited_users.append(lead)
        #file2.write(str(lead)+"\n")
        goto_id.click()
        sleep(randint(2,6))
        
        
        #get followers and following
        try:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
        except:
            followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/ul/li[2]/a/span')
        followers=get_int(followers_element.text)
        print("Followers :",followers)
        sleep(randint(4,10))
        try:
            following_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
        except:
            #followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
            print("Err")

        following=get_int(following_element.text)
        print("Following :",following)
        sleep(randint(4,10))

        
        if((following>followers) or (followers<300)):
            #user loop open
            print("Found user!!!!")
            try:
                #main user try
                #file1.write(lead+"\n")
                
                #follow the guy
                try:
                    #follow_probability=randint(1,10)
                    follow_probability=1
                    if (follow_probability<=2):
                        follow_button = webdriver.find_element_by_xpath('//button[text()="Follow"]')
                        follow_button.click()
                        sleep(randint(5,10))
                        #file1.write(lead+" Followed \n")
                except:
                    #file1.write(lead+" Error Following \n")
                    print(str(lead)+" Error Following \n")
                    pass
                sleep(randint(4,7))

                #then do the liking and commenting and messaging (if possible)
                #messaging
                try:
                    # Comments and tracker
                    messages=[' https://www.instagram.com/p/B-ZeWRwJuZR/  Do support the post with your valuable likes. Your appreciation really motivates me to expand my knowledge, develop & explore such softwares from the latest ai tech. All my code is also available on my github profile link. Thanks ❤️.',
                              'https://www.instagram.com/p/B_NKC5GjSBn/   I work as a small developer to make such models in machine learning! Do support me with your valuable likes!',
                              'https://www.instagram.com/p/B_NKC5GjSBn/  Do share if you like my posts! I really appreciate your support!',
                              'https://www.instagram.com/p/B-j1VbYJxzT/ If possible, do give me a thumbs up if you like my post. Such feedback motivates me to develop small softwares like these!',
                              'https://www.instagram.com/p/B-ZeWRwJuZR/ Do share my posts if you like #deeplearning and the latest ai tech!',
                              'Hey! Do check out my profile!!! I am a deep learning enthusiast trying to learn models!'

                             ]
                    message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
                    message_button.click()
                    sleep(randint(3,6))
                    message=random.choice(messages)
                    file1.write(lead+" Messaged "+message+" \n")
                    message_box=webdriver.find_elements_by_tag_name('textarea')
                    message_box[0].send_keys(message)
                    sleep(randint(2,4))
                    send_button=webdriver.find_element_by_xpath('//button[text()="Send"]')
                    send_button.click()
                    sleep(1)
                    info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
                    info_button.click()
                    move_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div/div[2]/div[2]/div[1]/button')
                    move_button.click()
                    sleep(randint(2,10))
                    #file1.write(" Sent message \n")
                    print("Sent message \n")
                except:
                    #file1.write(lead+" Messaged Failed "+message+" \n")
                    print(lead+" Messaging Failed "+message+" \n")
                    pass
                
                counter+=1
                
                webdriver.get('https://www.instagram.com/'+ lead + '/')
                
                #first get all post links of this user
                #best working
                user_posts=[]
                for i in range(10):
                    elems = webdriver.find_elements_by_xpath("//a[@href]")
                    for elem in elems:
                        post_link=elem.get_attribute("href")
                        #print(post_link)
                        if(re.search("^https://www.instagram.com/p/.", post_link)):
                            if post_link not in user_posts:
                                user_posts.append(post_link)
                    webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
                    if len(user_posts)>=500:
                        break
                    sleep(randint(2,4))
                print("Got user posts!!")
                
                
                #get posts to be liked recent posts preferred
                #probability play comes here
                length=len(user_posts)
                probabilities = [0] * length
                for i in range(length):
                    probabilities[i]=(length-i)/length
                probabilities = np.array(probabilities)
                probabilities /= probabilities.sum()  # normalize
                randomElement = choice(user_posts, p=probabilities)
                max_likes=10
                likes=[]
                for i in range(max_likes):
                    randomElement = choice(user_posts, p=probabilities)
                    likes.append(randomElement)
                #for each_like in likes:
                #print(user_posts.index(each_like))
                #everything happenning under main user try
                
                print("Travelled so far")
                #give actual likes and comments
                for each_like in likes:
                    try:
                        #file1.write(lead+" Post Liked - "+str(each_like)+" \n")
                        print(str(lead)+" Liking Post - "+str(each_like)+" \n")
                        #goto_post=webdriver.get(each_like)
                        webdriver.get(each_like)
                        sleep(randint(2,4))
                        like_buttons=[ '/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]',
                                  '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button',
                                  '/html/body/div[1]/section/main/div/div[1]/article/div[2]/section[1]/span[1]/button'
                                     ]
                        for idx in like_buttons:
                            try:
                                #liketry open
                                like_button=webdriver.find_element_by_xpath(idx)
                                like_button.click()
                                sleep(randint(2,4))
                                print(str(lead)+" Post Liked - "+str(each_like)+" \n")
                                #break
                                #liketry close
                            except:
                                #traceback.print_exc()
                                continue
                            finally:                 
                                # Comments and tracker
                                #comm_prob = randint(1,10)

                                comm_prob=10
                                comments=["Hey,I found your ID really cool! Mind checking back mine?",
                                          "Hey,I found your posts really awesome! Do checking back my profile too!",
                                          "I really enjoyed scrolling through your posts! Do like mine if you reciprocate!",
                                          "Hey,I found your feed really awesome! Do check out my profile too!",
                                          "Boo yah! I found your posts mind blowing! #Oneofthosefewgalleries",
                                          "Yohoo! Your instagram handle is really nice! ",
                                          "I love how expressive your work is. ;D ",
                                          "If any pic ever deserved a thumbs up it’s this one!",
                                          "I don’t know if you’re aware, but you're gonna be famous pretty soon. #GreatPicture :X",
                                          "Your feed is so aesthetic! I simply enjoyed it a lot! :)",
                                          "Thats a really dashing post!:0",
                                          "I really like your insta!:p"]
                                comment=random.choice(comments)
                                print("random comment chosen!")
                                #if comment probability>90% then only comment 
                                if comm_prob > 9:
                                    comment_box=webdriver.find_elements_by_tag_name('textarea')
                                    print("CommentBox successful")
                                    sleep(1)
                                    #print(comment_box)
                                    #for i, textarea in enumerate(comment_box):
                                    #print ('{} is at index {}'.format(textarea.text, i))

                                    comment_box[0].send_keys(str(comment))
                                    print("SendKeys successful")
                                    sleep(randint(2,4))
                                    send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
                                    print("SEnd buttonfind successful")
                                    send_button.click()
                                    print("SEnd buttonclick successful")
                                    #file1.write(lead+" Commented "+str(comment)+" \n")
                                    print(str(lead)+" Commented "+str(comment)+" \n")
                                    sleep(1)
                            
                    except:
                        print("Failed Post likes & comments")
                        traceback.print_exc()
                        continue
            except:
                #main user try exception
                #file1.write(lead+"Failed all loop operations"+" \n")
                print(str(lead)+"Failed all loop operations"+" \n")
                pass
    except:
        #file1.write(post+" - Failed all post operations"+" \n")
        print(str(post)+" - Failed all post operations"+" \n")
        pass

# %%
comment_box=webdriver.find_elements_by_tag_name('textarea')
comment_box[0].send_keys("comment")
send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
send_button.click()

# %%
first_thumbnail = webdriver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div') 
first_thumbnail.click()
first_th=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div/div[2]')
second_th= webdriver.find_element_by_xpath('/html/body/div[1]/section/main/article/div[1]/div/div/div[1]/div[2]/a/div/div[2]')
third_th= webdriver.find_element_by_xpath('/html/body/div[1]/section/main/article/div[1]/div/div/div[1]/div[3]/a/div/div[2]')
sleep(randint(3,6))

# %%
try:
    goto_id=webdriver.find_element_by_xpath('/html/body/div[3]/div[2]/div/article/header/div[2]/div[1]/div[1]/a')
except:
    goto_id=webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/header/div[2]/div[1]/div[1]/a')
finally:
    lead=goto_id.text
    print(lead)
    goto_id.click()
sleep(randint(2,6))

# %%
try:
    followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[2]/a')
except:
    followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/ul/li[2]/a/span')
def get_int(followers):
    if(re.search('k',followers)):
        followers=followers.replace('k','000')
    followers=followers.replace(',','')
    temp = re.findall(r'\d+', followers) 
    res = list(map(int, temp)) 
    return res[0]

followers=get_int(followers_element.text)
print("Followers :",followers)
sleep(randint(4,10))

# %%
try:
    following_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
except:
    #followers_element=webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/ul/li[3]/a/span')
    print("Err")

following=get_int(following_element.text)
print("Following :",following)
sleep(randint(4,10))

# %%
string = '/html/body/div[1]/section/main/div/div[2]/article/div/div/div[{}]/div[{}]/a/div/div[2]'
if((following>followers) or (followers<300)):
    #do something
    print(True)
    count=0
    row=0
    #get the account posts and like them one by one
    while(row<=6):
        row+=1
        for col in range(1,4):
            try:
                thumb_element=webdriver.find_element_by_xpath(string.format(row,col))
                sleep(randint(8,10))
            except:
                break
            count+=1
            print(count)

# %%
lead_link="https://www.instagram.com/"+lead+'/'

# %%
elems = webdriver.find_elements_by_xpath("//a[@href]")
posts=[]
for elem in elems:
    post_link=elem.get_attribute("href")
    try:
        if(post_link[26]=="p"):
            print(post_link)
    except:
        continue

# %%
for i in range(100):
    webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    sleep(randint(4,7))

# %%
elems = webdriver.find_elements_by_xpath("//a[@href]")
print(len(elems))
all_links=[]
posts=[]
for elem in elems:
    post_link=elem.get_attribute("href")
    #print(post_link)
    all_links.append(post_link)
    if(re.search("^https://www.instagram.com/p/.", post_link)):
        #print(post_link)
        posts.append(post_link)
#https://www.instagram.com/p/B_OsWytgKyD/
print(len(posts))
print(len(all_links))
#funny actually doesn't catch all links hmm

# %%
#best working
posts=[]
all_links=[]
for i in range(60):
    elems = webdriver.find_elements_by_xpath("//a[@href]")
    for elem in elems:
        post_link=elem.get_attribute("href")
        #print(post_link)
        if post_link not in all_links:
            all_links.append(post_link)
        if(re.search("^https://www.instagram.com/p/.", post_link)):
            if post_link not in posts:
                posts.append(post_link)
    webdriver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    sleep(randint(2,4))
print(len(posts))
print(len(all_links))

# %%
from numpy.random import choice
import numpy as np

# %%
#now we have all the post links from the lead username
#randomly choose some like posts
#recent posts are more likely to be preferred
from numpy.random import choice
import numpy as np
length=len(posts)
probabilities = [0] * length
for i in range(length):
    probabilities[i]=(length-i)/length
#print(probabilities[-20:])
#elements = ["first", "second", "third", "fourth", "fifth"]
#randomElement = choice(elements, p=probabilities)
#print (randomElement)
probabilities = np.array(probabilities)
probabilities /= probabilities.sum()  # normalize
randomElement = choice(posts, p=probabilities)
print (posts.index(randomElement))

# %%
#now we have all the post links from the lead username
#randomly choose some like posts
#recent posts are more likely to be preferred
max_likes=20
likes=[]
for i in range(max_likes):
    randomElement = choice(posts, p=probabilities)
    likes.append(randomElement)
def print_list(lst):
    for i in lst:
        print(i)
for each_like in likes:
    print(posts.index(each_like))

# %%
webdriver.quit()

# %%
print("https://www.instagram.com/p/B8RaBzWAxA3/" in all_links)

# %%
all_links=[]
links = webdriver.find_elements_by_tag_name("a")
for el in links:
    post_link=el.get_attribute("href")
    all_links.append(post_link)
#print(links.get_attribute("href"))
print(len(all_links))

# %%
all_links=[]
links = webdriver.find_elements_by_css_selector("a")
for el in links:
    post_link=el.get_attribute("href")
    all_links.append(post_link)
#print(links.get_attribute("href"))
print(len(all_links))

# %%
import time
def scroll(driver, timeout):
    scroll_pause_time = timeout

    # Get scroll height
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(scroll_pause_time)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            # If heights are the same it will exit the function
            break
        last_height = new_height

# %%
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
#https://dev.to/hellomrspaceman/python-selenium-infinite-scrolling-3o12

def all_links(url):
    driver.implicitly_wait(30)
    # driver.get(url) opens the page
    driver.get(url)
    # This starts the scrolling by passing the driver and a timeout
    scroll(driver, 5)
    # Once scroll returns bs4 parsers the page_source
    soup_a = BeautifulSoup(driver.page_source, 'lxml')
    # Them we close the driver as soup_a is storing the page source
    driver.close()

    # Empty array to store the links
    links = []

    # Looping through all the a elements in the page source
    for link in soup_a.find_all('a'):
        # link.get('href') gets the href/url out of the a element
        links.append(link.get('href'))

    return links

# %%
driver=webdriver
scroll(driver, 5)
# Once scroll returns bs4 parsers the page_source
soup_a = BeautifulSoup(driver.page_source, 'lxml')
# Them we close the driver as soup_a is storing the page source
#driver.close()

# Empty array to store the links
links = []

# Looping through all the a elements in the page source
for link in soup_a.find_all('a'):
    # link.get('href') gets the href/url out of the a element
    links.append(link.get('href'))
len(links)

# %%
#webdriver.quit()

# %%
string = '/html/body/div[1]/section/main/div/div[2]/article/div/div/div[{}]/div[{}]/a/div/div[2]'
row,col=1,2
thumb_element=webdriver.find_element_by_xpath(string.format(row,col))
thumb_element.click()

# %%
like_button=webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[1]')
like_button.click()
sleep(randint(2,4))

# %%
import random
#webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[1]/span[2]/button/svg').click()
comment_box = webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/textarea')
list_of_comments=['Nice work :)','Really cool!','Nice gallery!!','So cool! :)','I really enjoyed your insta handle.'
                 ,'Awesome work!','Your profile looks really amazing!','I really appreciate profiles like yours!']
comment=random.choice(list_of_comments)
comment_box.send_keys(comment)
sleep(randint(4,8))
post_button = webdriver.find_element_by_xpath('/html/body/div[4]/div[2]/div/article/div[2]/section[3]/div/form/button')
post_button.click()

# %%
close_post_button = webdriver.find_element_by_xpath('/html/body/div[4]/div[3]/button')
close_post_button.click()

# %%
id_details_button = webdriver.find_element_by_xpath('/html/body/div[1]/section/main/div/header/section/div[1]/div[1]/span/span[2]/button')
id_details_button.click()

# %%
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[1]/div[1]/a/div/div[2]')
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[1]/div[2]/a/div/div[2]')
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[1]/div[3]/a/div/div[2]')
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[2]/div[1]/a/div/div[2]')
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[2]/div[2]/a/div/div[2]')
('/html/body/div[1]/section/main/div/div[2]/article/div/div/div[2]/div[3]/a/div/div[2]')

# %%
str = '/html/body/div[1]/section/main/div/div[2]/article/div/div/div[{}]/div[{}]/a/div/div[2]'
print (str.format(1,2))

# %%
# Comments and tracker
import random
comm_prob = randint(1,10)
comm_prob=10
messages=['Hey,I found your ID really cool! Mind checking back mine?',
          'Hey,I found your posts really awesome! Do checking back my profile too!',
          'I really enjoyed scrolling through your posts! Do like mine if you reciprocate!',
          'Hey,I found your feed really awesome! Do check out my profile too!',
          'Boo yah! I found your posts mind blowing! #Oneofthosefewgalleries',
          'Yohoo! Your instagram handle is really nice! ',
          'I love how expressive your work is. ;D ',
          'If any pic ever deserved a thumbs up it’s this one!',
          "I don’t know if you’re aware, but you're gonna be famous pretty soon. #GreatPicture :X",
          "Your feed is so aesthetic! I simply enjoyed it a lot! :)",
          "Thats a really dashing post!:0",
          "I really like your insta!:p"
         ]
message=random.choice(messages)
#if comment probability>70% then only comment - 80%
if comm_prob > 7:
    #comments += 1
    #webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[2]/div/div[2]/div/div/div[2]/textarea').click()
    #comment_box = webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/section[3]/div/form/textarea')
    comment_box=webdriver.find_elements_by_tag_name('textarea')
    print(comment_box)
    for i, textarea in enumerate(comment_box):
        print ('{} is at index {}'.format(textarea.text, i))

    comment_box[0].send_keys(message)
    sleep(randint(2,4))
    send_button=webdriver.find_element_by_xpath('//button[text()="Post"]')
    send_button.click()
    sleep(1)

# %%
# Comments and tracker
import random
comm_prob = randint(1,10)
comm_prob=10
messages=[' https://www.instagram.com/p/B-ZeWRwJuZR/  Do support the post with your valuable likes. Your appreciation really motivates me to expand my knowledge, develop & explore such softwares from the latest ai tech. All my code is also available on my github profile link. Thanks ❤️.',
          'https://www.instagram.com/p/B_NKC5GjSBn/   I work as a small developer to make such models in machine learning! Do support me with your valuable likes!',
          'https://www.instagram.com/p/B_NKC5GjSBn/  Do share if you like my posts! I really appreciate your support!',
          'https://www.instagram.com/p/B-j1VbYJxzT/ If possible, do give me a thumbs up if you like my post. Such feedback motivates me to develop small softwares like these!',
          'https://www.instagram.com/p/B-ZeWRwJuZR/ Do share my posts if you like #deeplearning and the latest ai tech!',
          'Hey! Do check out my profile!!! I am a deep learning enthusiast trying to learn models!'
          
         ]
message_button=webdriver.find_element_by_xpath('//button[text()="Message"]')
message_button.click()
sleep(randint(3,6))
message=random.choice(messages)
message_box=webdriver.find_elements_by_tag_name('textarea')
message_box[0].send_keys(message)
sleep(randint(2,4))
send_button=webdriver.find_element_by_xpath('//button[text()="Send"]')
send_button.click()
sleep(1)
info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
info_button.click()
move_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div/div[2]/div[2]/div[1]/button')
move_button.click()

# %%
try:
    info_button=webdriver.find_element_by_xpath('/html/body/div[1]/section/div/div[2]/div/div/div[2]/div[1]/div/div/div[3]/button')
    info_button.click
except:
    print("Failed to move to general!")

# %%
webdriver.quit()

# %%
hashtag_list = ['influencer', 'deeplearning']

prev_user_list = [] # if it's the first time you run it, use this line and comment the two below
#prev_user_list = pd.read_csv('20181203-224633_users_followed_list.csv', delimiter=',').iloc[:,1:2] # useful to build a user log
#prev_user_list = list(prev_user_list['0'])

new_followed = []
tag = -1
followed = 0
likes = 0
comments = 0

for hashtag in hashtag_list:
    tag += 1
    webdriver.get('https://www.instagram.com/explore/tags/'+ hashtag_list[tag] + '/')
    sleep(5)
    first_thumbnail = webdriver.find_element_by_xpath('//*[@id="react-root"]/section/main/article/div[1]/div/div/div[1]/div[1]/a/div')
    
    first_thumbnail.click()
    sleep(randint(1,2))    
    try:        
        for x in range(1,10):
            username = webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/header/div[2]/div[1]/div[1]/h2/a').text
            
            if username not in prev_user_list:
                # If we already follow, do not unfollow
                if webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/header/div[2]/div[1]/div[2]/button').text == 'Follow':
                    
                    webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/header/div[2]/div[1]/div[2]/button').click()
                    
                    new_followed.append(username)
                    followed += 1

                    # Liking the picture
                    button_like = webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/section[1]/span[1]/button/span')
                    
                    button_like.click()
                    likes += 1
                    sleep(randint(18,25))

                    # Comments and tracker
                    comm_prob = randint(1,10)
                    #if comment probability>70% then only comment
                    print('{}_{}: {}'.format(hashtag, x,comm_prob))
                    if comm_prob > 7:
                        comments += 1
                        webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/section[1]/span[2]/button/span').click()
                        comment_box = webdriver.find_element_by_xpath('/html/body/div[3]/div/div[2]/div/article/div[2]/section[3]/div/form/textarea')

                        if (comm_prob < 7):
                            comment_box.send_keys('Really cool!')
                            sleep(1)
                        elif (comm_prob > 6) and (comm_prob < 9):
                            comment_box.send_keys('Nice work :)')
                            sleep(1)
                        elif comm_prob == 9:
                            comment_box.send_keys('Nice gallery!!')
                            sleep(1)
                        elif comm_prob == 10:
                            comment_box.send_keys('So cool! :)')
                            sleep(1)
                        # Enter to post comment
                        comment_box.send_keys(Keys.ENTER)
                        sleep(randint(22,28))

                # Next picture
                webdriver.find_element_by_link_text('Next').click()
                sleep(randint(25,29))
            else:
                webdriver.find_element_by_link_text('Next').click()
                sleep(randint(20,26))
    # some hashtag stops refreshing photos (it may happen sometimes), it continues to the next
    except:
        continue

for n in range(0,len(new_followed)):
    prev_user_list.append(new_followed[n])
    
updated_user_df = pd.DataFrame(prev_user_list)
updated_user_df.to_csv('{}_users_followed_list.csv'.format(strftime("%Y%m%d-%H%M%S")))
print('Liked {} photos.'.format(likes))
print('Commented {} photos.'.format(comments))
print('Followed {} new people.'.format(followed))

# %%
webdriver.quit()

# %%
mobile_emulation = { 
			#"deviceName": "Apple iPhone 3GS"
			#"deviceName": "Apple iPhone 4"
			#"deviceName": "Apple iPhone 5"
			#"deviceName": "Apple iPhone 6"
			#"deviceName": "Apple iPhone 6 Plus"
			#"deviceName": "BlackBerry Z10"
			#"deviceName": "BlackBerry Z30"
			#"deviceName": "Google Nexus 4"
			"deviceName": "Google Nexus 5"
			#"deviceName": "Google Nexus S"
			#"deviceName": "HTC Evo, Touch HD, Desire HD, Desire"
			#"deviceName": "HTC One X, EVO LTE"
			#"deviceName": "HTC Sensation, Evo 3D"
			#"deviceName": "LG Optimus 2X, Optimus 3D, Optimus Black"
			#"deviceName": "LG Optimus G"
			#"deviceName": "LG Optimus LTE, Optimus 4X HD" 
			#"deviceName": "LG Optimus One"
			#"deviceName": "Motorola Defy, Droid, Droid X, Milestone"
			#"deviceName": "Motorola Droid 3, Droid 4, Droid Razr, Atrix 4G, Atrix 2"
			#"deviceName": "Motorola Droid Razr HD"
			#"deviceName": "Nokia C5, C6, C7, N97, N8, X7"
			#"deviceName": "Nokia Lumia 7X0, Lumia 8XX, Lumia 900, N800, N810, N900"
			#"deviceName": "Samsung Galaxy Note 3"
			#"deviceName": "Samsung Galaxy Note II"
			#"deviceName": "Samsung Galaxy Note"
			#"deviceName": "Samsung Galaxy S III, Galaxy Nexus"
			#"deviceName": "Samsung Galaxy S, S II, W"
			#"deviceName": "Samsung Galaxy S4"
			#"deviceName": "Sony Xperia S, Ion"
			#"deviceName": "Sony Xperia Sola, U"
			#"deviceName": "Sony Xperia Z, Z1"
			#"deviceName": "Amazon Kindle Fire HDX 7″"
			#"deviceName": "Amazon Kindle Fire HDX 8.9″"
			#"deviceName": "Amazon Kindle Fire (First Generation)"
			#"deviceName": "Apple iPad 1 / 2 / iPad Mini"
			#"deviceName": "Apple iPad 3 / 4"
			#"deviceName": "BlackBerry PlayBook"
			#"deviceName": "Google Nexus 10"
			#"deviceName": "Google Nexus 7 2"
			#"deviceName": "Google Nexus 7"
			#"deviceName": "Motorola Xoom, Xyboard"
			#"deviceName": "Samsung Galaxy Tab 7.7, 8.9, 10.1"
			#"deviceName": "Samsung Galaxy Tab"
			#"deviceName": "Notebook with touch"
			
			# Or specify a specific build using the following two arguments
			#"deviceMetrics": { "width": 360, "height": 640, "pixelRatio": 3.0 },
		    #"userAgent": "Mozilla/5.0 (Linux; Android 4.2.1; en-us; Nexus 5 Build/JOP40D) AppleWebKit/535.19 (KHTML, like Gecko) Chrome/18.0.1025.166 Mobile Safari/535.19" }
		}

# %%
#https://gist.github.com/devinmancuso/ec8ae08fa73402e45bf1

# %%
from time import sleep
from selenium import webdriver

browser = webdriver.Firefox(executable_path=r'C:/Users/farha/Downloads/geckodriver-v0.26.0-win64/geckodriver.exe')

browser.get('https://www.instagram.com/')

login_link = browser.find_element_by_xpath("//a[text()='Log in']")
login_link.click()

sleep(5)

browser.close()

# %%
from instapy import InstaPy

InstaPy(username="i.am.the.swagger", password="mypassword").login()

# %%
from selenium import webdriver
driver = webdriver.Firefox(executable_path=r'C:/Users/farha/Downloads/geckodriver-v0.26.0-win64/geckodriver.exe')
driver.get('http://inventwithpython.com')

# %%
import datetime
#https://stackoverflow.com/questions/26455616/how-can-i-create-basic-timestamps-or-dates-python-3-4
print('Timestamp: {:%Y-%m-%d %H:%M:%S}'.format(datetime.datetime.now()))
print('Timestamp: {:%Y-%b-%d %H:%M:%S}'.format(datetime.datetime.now()))

print('Date now: %s' % datetime.datetime.now())
print('Date today: %s' % datetime.date.today())

today = datetime.date.today()
print("Today's date is {:%b, %d %Y}".format(today))

schedule = '{:%b, %d %Y}'.format(today) + ' - 6 PM to 10 PM Pacific'
schedule2 = '{:%B, %d %Y}'.format(today) + ' - 1 PM to 6 PM Central'
print('Maintenance: %s' % schedule)
print('Maintenance: %s' % schedule2)
